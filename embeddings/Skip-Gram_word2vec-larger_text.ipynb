# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile
from glob import glob

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)

        
        
text = ''
for file in glob('texts/*.txt'):
    with open(file) as f:
        text += f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['little', 'women', '<NEW_LINE>', '<NEW_LINE>', '<NEW_LINE>', 'by', '<NEW_LINE>', '<NEW_LINE>', 'louisa', 'may', '<NEW_LINE>', '<NEW_LINE>', '<NEW_LINE>', '<NEW_LINE>', '<NEW_LINE>', 'contents', '<NEW_LINE>', '<NEW_LINE>', '<NEW_LINE>', 'part', '1', '<NEW_LINE>', '<NEW_LINE>', 'one', 'playing', 'pilgrims', '<NEW_LINE>', 'two', 'a', 'merry']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 6940936
# Unique words: 26813

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter

word_counts = Counter(int_words)
print("the: ", word_counts[vocab_to_int['the']])
# Out:
# the:  290228

# %%
train_words = []
from random import random
import numpy as np

def discard_prob(word_count, total_count, threshold):
    return 1 - np.sqrt(threshold/(word_count/total_count))

threshold = 1e-5

# Calculate the discard prob and store
total_words = len(int_words)
p_drop = {word: discard_prob(count, total_words, threshold) for word, count in word_counts.items()}

train_words = [word for word in int_words if p_drop[word] < random()]

print(train_words[:10])
# Out:
# [18236, 3321, 2039, 8804, 4013, 11134, 1249, 2786, 1383, 5298]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
from random import randint

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    
    sub_window = randint(1, window_size)
    
    targets = [words[idx - i - 1] for i in range(sub_window) if idx-i-1 >= 0]
    targets += [words[idx + i + 1] for i in range(sub_window) if idx+i+1 < len(words)]
#     targets = list(set(targets))
    targets = set(targets)
    return list(targets)

# %%
get_target(int_words, 500, window_size=3)
# Out:
# [3, 82, 212, 21, 379, 220]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1), name='embedding')
    
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], mean=0, stddev=0.1))
    
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, 
                                      biases=softmax_b, 
                                      labels=labels, 
                                      inputs=embed, 
                                      num_sampled=n_sampled, 
                                      num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints_large
# Out:
# mkdir: cannot create directory ‘checkpoints_large’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 30
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 10000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints_large/large_text.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/30 Iteration: 100 Avg. Training loss: 5.6962 0.0558 sec/batch
# Epoch 1/30 Iteration: 200 Avg. Training loss: 5.3633 0.0543 sec/batch
# Epoch 1/30 Iteration: 300 Avg. Training loss: 5.4318 0.0550 sec/batch
# Epoch 1/30 Iteration: 400 Avg. Training loss: 5.4679 0.0553 sec/batch
# Epoch 1/30 Iteration: 500 Avg. Training loss: 5.6382 0.0548 sec/batch
# Epoch 1/30 Iteration: 600 Avg. Training loss: 5.4505 0.0552 sec/batch
# Epoch 1/30 Iteration: 700 Avg. Training loss: 5.4620 0.0545 sec/batch
# Epoch 1/30 Iteration: 800 Avg. Training loss: 5.2717 0.0548 sec/batch
# Epoch 1/30 Iteration: 900 Avg. Training loss: 4.9926 0.0545 sec/batch
# Epoch 1/30 Iteration: 1000 Avg. Training loss: 5.2278 0.0550 sec/batch
# Epoch 1/30 Iteration: 1100 Avg. Training loss: 5.1209 0.0548 sec/batch
# Epoch 1/30 Iteration: 1200 Avg. Training loss: 5.0224 0.0548 sec/batch
# Epoch 1/30 Iteration: 1300 Avg. Training loss: 4.9140 0.0550 sec/batch
# Epoch 2/30 Iteration: 1400 Avg. Training loss: 4.9466 0.0256 sec/batch
# Epoch 2/30 Iteration: 1500 Avg. Training loss: 4.7951 0.0547 sec/batch
# Epoch 2/30 Iteration: 1600 Avg. Training loss: 4.7057 0.0547 sec/batch
# Epoch 2/30 Iteration: 1700 Avg. Training loss: 4.8030 0.0547 sec/batch
# Epoch 2/30 Iteration: 1800 Avg. Training loss: 4.7667 0.0554 sec/batch
# Epoch 2/30 Iteration: 1900 Avg. Training loss: 4.7652 0.0549 sec/batch
# Epoch 2/30 Iteration: 2000 Avg. Training loss: 4.7377 0.0548 sec/batch
# Epoch 2/30 Iteration: 2100 Avg. Training loss: 4.8305 0.0552 sec/batch
# Epoch 2/30 Iteration: 2200 Avg. Training loss: 4.6544 0.0560 sec/batch
# Epoch 2/30 Iteration: 2300 Avg. Training loss: 4.6262 0.0556 sec/batch
# Epoch 2/30 Iteration: 2400 Avg. Training loss: 4.7609 0.0549 sec/batch
# Epoch 2/30 Iteration: 2500 Avg. Training loss: 4.6807 0.0545 sec/batch
# Epoch 2/30 Iteration: 2600 Avg. Training loss: 4.5342 0.0545 sec/batch
# Epoch 2/30 Iteration: 2700 Avg. Training loss: 4.5960 0.0549 sec/batch
# Epoch 3/30 Iteration: 2800 Avg. Training loss: 4.6543 0.0517 sec/batch
# Epoch 3/30 Iteration: 2900 Avg. Training loss: 4.4907 0.0550 sec/batch
# Epoch 3/30 Iteration: 3000 Avg. Training loss: 4.5445 0.0548 sec/batch
# Epoch 3/30 Iteration: 3100 Avg. Training loss: 4.5134 0.0545 sec/batch
# Epoch 3/30 Iteration: 3200 Avg. Training loss: 4.5913 0.0550 sec/batch
# Epoch 3/30 Iteration: 3300 Avg. Training loss: 4.5970 0.0548 sec/batch
# Epoch 3/30 Iteration: 3400 Avg. Training loss: 4.5820 0.0556 sec/batch
# Epoch 3/30 Iteration: 3500 Avg. Training loss: 4.5230 0.0543 sec/batch
# Epoch 3/30 Iteration: 3600 Avg. Training loss: 4.4227 0.0545 sec/batch
# Epoch 3/30 Iteration: 3700 Avg. Training loss: 4.5689 0.0546 sec/batch
# Epoch 3/30 Iteration: 3800 Avg. Training loss: 4.5286 0.0549 sec/batch
# Epoch 3/30 Iteration: 3900 Avg. Training loss: 4.4590 0.0544 sec/batch
# Epoch 3/30 Iteration: 4000 Avg. Training loss: 4.3908 0.0547 sec/batch
# Epoch 4/30 Iteration: 4100 Avg. Training loss: 4.5345 0.0226 sec/batch
# Epoch 4/30 Iteration: 4200 Avg. Training loss: 4.4422 0.0548 sec/batch
# Epoch 4/30 Iteration: 4300 Avg. Training loss: 4.3238 0.0542 sec/batch
# Epoch 4/30 Iteration: 4400 Avg. Training loss: 4.4664 0.0553 sec/batch
# Epoch 4/30 Iteration: 4500 Avg. Training loss: 4.4284 0.0551 sec/batch
# Epoch 4/30 Iteration: 4600 Avg. Training loss: 4.4626 0.0548 sec/batch
# Epoch 4/30 Iteration: 4700 Avg. Training loss: 4.3979 0.0547 sec/batch
# Epoch 4/30 Iteration: 4800 Avg. Training loss: 4.4534 0.0549 sec/batch
# Epoch 4/30 Iteration: 4900 Avg. Training loss: 4.3014 0.0544 sec/batch
# Epoch 4/30 Iteration: 5000 Avg. Training loss: 4.3286 0.0556 sec/batch
# Epoch 4/30 Iteration: 5100 Avg. Training loss: 4.4544 0.0552 sec/batch
# Epoch 4/30 Iteration: 5200 Avg. Training loss: 4.3502 0.0551 sec/batch
# Epoch 4/30 Iteration: 5300 Avg. Training loss: 4.1591 0.0550 sec/batch
# Epoch 4/30 Iteration: 5400 Avg. Training loss: 4.3361 0.0544 sec/batch
# Epoch 5/30 Iteration: 5500 Avg. Training loss: 4.4064 0.0485 sec/batch
# Epoch 5/30 Iteration: 5600 Avg. Training loss: 4.2782 0.0547 sec/batch
# Epoch 5/30 Iteration: 5700 Avg. Training loss: 4.2633 0.0546 sec/batch
# Epoch 5/30 Iteration: 5800 Avg. Training loss: 4.2463 0.0538 sec/batch
# Epoch 5/30 Iteration: 5900 Avg. Training loss: 4.3834 0.0542 sec/batch
# Epoch 5/30 Iteration: 6000 Avg. Training loss: 4.3649 0.0562 sec/batch
# Epoch 5/30 Iteration: 6100 Avg. Training loss: 4.3481 0.0539 sec/batch
# Epoch 5/30 Iteration: 6200 Avg. Training loss: 4.2713 0.0533 sec/batch
# Epoch 5/30 Iteration: 6300 Avg. Training loss: 4.1193 0.0536 sec/batch
# Epoch 5/30 Iteration: 6400 Avg. Training loss: 4.3379 0.0541 sec/batch
# Epoch 5/30 Iteration: 6500 Avg. Training loss: 4.3198 0.0541 sec/batch
# Epoch 5/30 Iteration: 6600 Avg. Training loss: 4.1445 0.0544 sec/batch
# Epoch 5/30 Iteration: 6700 Avg. Training loss: 4.0738 0.0539 sec/batch
# Epoch 6/30 Iteration: 6800 Avg. Training loss: 4.3538 0.0189 sec/batch
# Epoch 6/30 Iteration: 6900 Avg. Training loss: 4.2582 0.0540 sec/batch
# Epoch 6/30 Iteration: 7000 Avg. Training loss: 4.1401 0.0541 sec/batch
# Epoch 6/30 Iteration: 7100 Avg. Training loss: 4.2433 0.0538 sec/batch
# Epoch 6/30 Iteration: 7200 Avg. Training loss: 4.2356 0.0534 sec/batch
# Epoch 6/30 Iteration: 7300 Avg. Training loss: 4.3114 0.0539 sec/batch
# Epoch 6/30 Iteration: 7400 Avg. Training loss: 4.2270 0.0539 sec/batch
# Epoch 6/30 Iteration: 7500 Avg. Training loss: 4.2664 0.0536 sec/batch
# Epoch 6/30 Iteration: 7600 Avg. Training loss: 4.1127 0.0533 sec/batch
# Epoch 6/30 Iteration: 7700 Avg. Training loss: 4.1561 0.0536 sec/batch
# Epoch 6/30 Iteration: 7800 Avg. Training loss: 4.3036 0.0539 sec/batch
# Epoch 6/30 Iteration: 7900 Avg. Training loss: 4.2158 0.0537 sec/batch
# Epoch 6/30 Iteration: 8000 Avg. Training loss: 3.9100 0.0537 sec/batch
# Epoch 6/30 Iteration: 8100 Avg. Training loss: 4.2048 0.0540 sec/batch
# Epoch 7/30 Iteration: 8200 Avg. Training loss: 4.2737 0.0443 sec/batch
# Epoch 7/30 Iteration: 8300 Avg. Training loss: 4.1635 0.0537 sec/batch
# Epoch 7/30 Iteration: 8400 Avg. Training loss: 4.1237 0.0548 sec/batch
# Epoch 7/30 Iteration: 8500 Avg. Training loss: 4.1945 0.0551 sec/batch
# Epoch 7/30 Iteration: 8600 Avg. Training loss: 4.2291 0.0540 sec/batch
# Epoch 7/30 Iteration: 8700 Avg. Training loss: 4.2626 0.0538 sec/batch
# Epoch 7/30 Iteration: 8800 Avg. Training loss: 4.2068 0.0533 sec/batch
# Epoch 7/30 Iteration: 8900 Avg. Training loss: 4.1259 0.0534 sec/batch
# Epoch 7/30 Iteration: 9000 Avg. Training loss: 4.0203 0.0536 sec/batch
# Epoch 7/30 Iteration: 9100 Avg. Training loss: 4.2367 0.0541 sec/batch
# Epoch 7/30 Iteration: 9200 Avg. Training loss: 4.2006 0.0540 sec/batch
# Epoch 7/30 Iteration: 9300 Avg. Training loss: 4.0137 0.0549 sec/batch
# Epoch 7/30 Iteration: 9400 Avg. Training loss: 3.9591 0.0552 sec/batch
# Epoch 8/30 Iteration: 9500 Avg. Training loss: 4.2221 0.0158 sec/batch
# Epoch 8/30 Iteration: 9600 Avg. Training loss: 4.1686 0.0536 sec/batch
# Epoch 8/30 Iteration: 9700 Avg. Training loss: 4.0768 0.0539 sec/batch
# Epoch 8/30 Iteration: 9800 Avg. Training loss: 4.1891 0.0552 sec/batch
# Epoch 8/30 Iteration: 9900 Avg. Training loss: 4.1465 0.0542 sec/batch
# Epoch 8/30 Iteration: 10000 Avg. Training loss: 4.2195 0.0537 sec/batch
# Nearest to like: fill, swayed, barbed, whither, artists, greyish, glued, widows,
# Nearest to she: thunder, herself, unselfish, herring, ornament, kirílovich, creatures, git,
# Nearest to i: pasha, loophole, knew'st, drubetskóy, vrede, perceive, tough, “really,
# Nearest to when: bombs, would, superstition, lambton, speck, storm, weather, artilleryman,
# Nearest to has: enticed, offers, o’clock, illness, quarts, boylan, distracting, description,
# Nearest to any: eunuchs, _have_, muddled, kurágin’s, companions, demanded, enjoin, reproduced,
# Nearest to could: hastily, sympathetic, “more, petals, terrifies, being, wasted, listener,
# Nearest to other: cease, unemployed, idolatry, warranted, invisible, savannah, ‘there’s, shifted,
# Nearest to box: sweetness, peeps, quoted, ear, pallor, hoarded, disdain, harshness,
# Nearest to darkness: strung, banking, souvenirs, descends, boom, wan, diffusion, pollution,
# Nearest to hearing: attempting, singularly, mihailov, reproaching, quartermaster, packet, repnín, schooles,
# Nearest to meeting: scrutinizing, disengage, lizaveta, moth, asks, italics, humored, biggest,
# Nearest to 3: 501, taunts, 1/2, £, quotes, newby, higgins, card,
# Nearest to christ: origin, offerings, technique, understanding, god, julie, methodical, commeth,
# Nearest to pride: renaissance, mischievous, dishonor, 'we, relapse, emotion, excel, bolkónski,
# Nearest to brave: girded, dig, glaring, blindness, apollo, flaws, tremendously, goddess,
# Epoch 8/30 Iteration: 10100 Avg. Training loss: 4.1836 0.0542 sec/batch
# Epoch 8/30 Iteration: 10200 Avg. Training loss: 4.1694 0.0536 sec/batch
# Epoch 8/30 Iteration: 10300 Avg. Training loss: 4.0580 0.0535 sec/batch
# Epoch 8/30 Iteration: 10400 Avg. Training loss: 4.0431 0.0540 sec/batch
# Epoch 8/30 Iteration: 10500 Avg. Training loss: 4.2182 0.0549 sec/batch
# Epoch 8/30 Iteration: 10600 Avg. Training loss: 4.1214 0.0538 sec/batch
# Epoch 8/30 Iteration: 10700 Avg. Training loss: 3.7974 0.0549 sec/batch
# Epoch 8/30 Iteration: 10800 Avg. Training loss: 4.0856 0.0541 sec/batch
# Epoch 9/30 Iteration: 10900 Avg. Training loss: 4.2473 0.0411 sec/batch
# Epoch 9/30 Iteration: 11000 Avg. Training loss: 4.0231 0.0544 sec/batch
# Epoch 9/30 Iteration: 11100 Avg. Training loss: 4.0780 0.0541 sec/batch
# Epoch 9/30 Iteration: 11200 Avg. Training loss: 4.0864 0.0535 sec/batch
# Epoch 9/30 Iteration: 11300 Avg. Training loss: 4.1685 0.0558 sec/batch
# Epoch 9/30 Iteration: 11400 Avg. Training loss: 4.1954 0.0542 sec/batch
# Epoch 9/30 Iteration: 11500 Avg. Training loss: 4.1818 0.0537 sec/batch
# Epoch 9/30 Iteration: 11600 Avg. Training loss: 4.0774 0.0535 sec/batch
# Epoch 9/30 Iteration: 11700 Avg. Training loss: 3.9171 0.0535 sec/batch
# Epoch 9/30 Iteration: 11800 Avg. Training loss: 4.1296 0.0539 sec/batch
# Epoch 9/30 Iteration: 11900 Avg. Training loss: 4.1555 0.0541 sec/batch
# Epoch 9/30 Iteration: 12000 Avg. Training loss: 3.9071 0.0541 sec/batch
# Epoch 9/30 Iteration: 12100 Avg. Training loss: 3.8599 0.0542 sec/batch
# Epoch 10/30 Iteration: 12200 Avg. Training loss: 4.1540 0.0124 sec/batch
# Epoch 10/30 Iteration: 12300 Avg. Training loss: 4.1300 0.0536 sec/batch
# Epoch 10/30 Iteration: 12400 Avg. Training loss: 3.9999 0.0544 sec/batch
# Epoch 10/30 Iteration: 12500 Avg. Training loss: 4.1247 0.0533 sec/batch
# Epoch 10/30 Iteration: 12600 Avg. Training loss: 4.0481 0.0539 sec/batch
# Epoch 10/30 Iteration: 12700 Avg. Training loss: 4.1577 0.0537 sec/batch
# Epoch 10/30 Iteration: 12800 Avg. Training loss: 4.1485 0.0543 sec/batch
# Epoch 10/30 Iteration: 12900 Avg. Training loss: 4.1268 0.0541 sec/batch
# Epoch 10/30 Iteration: 13000 Avg. Training loss: 3.9850 0.0539 sec/batch
# Epoch 10/30 Iteration: 13100 Avg. Training loss: 3.9224 0.0542 sec/batch
# Epoch 10/30 Iteration: 13200 Avg. Training loss: 4.1568 0.0547 sec/batch
# Epoch 10/30 Iteration: 13300 Avg. Training loss: 4.0903 0.0545 sec/batch
# Epoch 10/30 Iteration: 13400 Avg. Training loss: 3.7363 0.0539 sec/batch
# Epoch 10/30 Iteration: 13500 Avg. Training loss: 4.0367 0.0544 sec/batch
# Epoch 11/30 Iteration: 13600 Avg. Training loss: 4.1728 0.0380 sec/batch
# Epoch 11/30 Iteration: 13700 Avg. Training loss: 3.9684 0.0541 sec/batch
# Epoch 11/30 Iteration: 13800 Avg. Training loss: 4.0169 0.0540 sec/batch
# Epoch 11/30 Iteration: 13900 Avg. Training loss: 4.0383 0.0539 sec/batch
# Epoch 11/30 Iteration: 14000 Avg. Training loss: 4.1019 0.0539 sec/batch
# Epoch 11/30 Iteration: 14100 Avg. Training loss: 4.1553 0.0541 sec/batch
# Epoch 11/30 Iteration: 14200 Avg. Training loss: 4.1166 0.0542 sec/batch
# Epoch 11/30 Iteration: 14300 Avg. Training loss: 4.0161 0.0539 sec/batch
# Epoch 11/30 Iteration: 14400 Avg. Training loss: 3.8890 0.0537 sec/batch
# Epoch 11/30 Iteration: 14500 Avg. Training loss: 4.0220 0.0540 sec/batch
# Epoch 11/30 Iteration: 14600 Avg. Training loss: 4.1216 0.0545 sec/batch
# Epoch 11/30 Iteration: 14700 Avg. Training loss: 3.8685 0.0538 sec/batch
# Epoch 11/30 Iteration: 14800 Avg. Training loss: 3.8072 0.0541 sec/batch
# Epoch 12/30 Iteration: 14900 Avg. Training loss: 4.0829 0.0093 sec/batch
# Epoch 12/30 Iteration: 15000 Avg. Training loss: 4.0938 0.0543 sec/batch
# Epoch 12/30 Iteration: 15100 Avg. Training loss: 3.9936 0.0544 sec/batch
# Epoch 12/30 Iteration: 15200 Avg. Training loss: 4.0388 0.0546 sec/batch
# Epoch 12/30 Iteration: 15300 Avg. Training loss: 4.0238 0.0544 sec/batch
# Epoch 12/30 Iteration: 15400 Avg. Training loss: 4.0898 0.0540 sec/batch
# Epoch 12/30 Iteration: 15500 Avg. Training loss: 4.0944 0.0540 sec/batch
# Epoch 12/30 Iteration: 15600 Avg. Training loss: 4.0713 0.0542 sec/batch
# Epoch 12/30 Iteration: 15700 Avg. Training loss: 3.9594 0.0538 sec/batch
# Epoch 12/30 Iteration: 15800 Avg. Training loss: 3.8583 0.0539 sec/batch
# Epoch 12/30 Iteration: 15900 Avg. Training loss: 4.1193 0.0541 sec/batch
# Epoch 12/30 Iteration: 16000 Avg. Training loss: 4.0434 0.0536 sec/batch
# Epoch 12/30 Iteration: 16100 Avg. Training loss: 3.7073 0.0536 sec/batch
# Epoch 12/30 Iteration: 16200 Avg. Training loss: 3.9418 0.0539 sec/batch
# Epoch 13/30 Iteration: 16300 Avg. Training loss: 4.1205 0.0348 sec/batch
# Epoch 13/30 Iteration: 16400 Avg. Training loss: 3.9262 0.0541 sec/batch
# Epoch 13/30 Iteration: 16500 Avg. Training loss: 3.9903 0.0539 sec/batch
# Epoch 13/30 Iteration: 16600 Avg. Training loss: 3.9915 0.0541 sec/batch
# Epoch 13/30 Iteration: 16700 Avg. Training loss: 4.0594 0.0542 sec/batch
# Epoch 13/30 Iteration: 16800 Avg. Training loss: 4.0902 0.0537 sec/batch
# Epoch 13/30 Iteration: 16900 Avg. Training loss: 4.0823 0.0541 sec/batch
# Epoch 13/30 Iteration: 17000 Avg. Training loss: 4.0104 0.0537 sec/batch
# Epoch 13/30 Iteration: 17100 Avg. Training loss: 3.8468 0.0540 sec/batch
# Epoch 13/30 Iteration: 17200 Avg. Training loss: 3.9644 0.0544 sec/batch
# Epoch 13/30 Iteration: 17300 Avg. Training loss: 4.0793 0.0541 sec/batch
# Epoch 13/30 Iteration: 17400 Avg. Training loss: 3.8618 0.0536 sec/batch
# Epoch 13/30 Iteration: 17500 Avg. Training loss: 3.7189 0.0542 sec/batch
# Epoch 14/30 Iteration: 17600 Avg. Training loss: 4.0918 0.0061 sec/batch
# Epoch 14/30 Iteration: 17700 Avg. Training loss: 4.0726 0.0544 sec/batch
# Epoch 14/30 Iteration: 17800 Avg. Training loss: 3.9226 0.0540 sec/batch
# Epoch 14/30 Iteration: 17900 Avg. Training loss: 3.9881 0.0541 sec/batch
# Epoch 14/30 Iteration: 18000 Avg. Training loss: 3.9826 0.0540 sec/batch
# Epoch 14/30 Iteration: 18100 Avg. Training loss: 4.0915 0.0536 sec/batch
# Epoch 14/30 Iteration: 18200 Avg. Training loss: 4.0619 0.0544 sec/batch
# Epoch 14/30 Iteration: 18300 Avg. Training loss: 4.0802 0.0542 sec/batch
# Epoch 14/30 Iteration: 18400 Avg. Training loss: 3.9082 0.0542 sec/batch
# Epoch 14/30 Iteration: 18500 Avg. Training loss: 3.8056 0.0541 sec/batch
# Epoch 14/30 Iteration: 18600 Avg. Training loss: 4.0839 0.0534 sec/batch
# Epoch 14/30 Iteration: 18700 Avg. Training loss: 4.0245 0.0540 sec/batch
# Epoch 14/30 Iteration: 18800 Avg. Training loss: 3.7154 0.0539 sec/batch
# Epoch 14/30 Iteration: 18900 Avg. Training loss: 3.8859 0.0541 sec/batch
# Epoch 15/30 Iteration: 19000 Avg. Training loss: 4.0791 0.0317 sec/batch
# Epoch 15/30 Iteration: 19100 Avg. Training loss: 3.9176 0.0538 sec/batch
# Epoch 15/30 Iteration: 19200 Avg. Training loss: 3.9627 0.0536 sec/batch
# Epoch 15/30 Iteration: 19300 Avg. Training loss: 3.9963 0.0538 sec/batch
# Epoch 15/30 Iteration: 19400 Avg. Training loss: 4.0215 0.0540 sec/batch
# Epoch 15/30 Iteration: 19500 Avg. Training loss: 4.0688 0.0547 sec/batch
# Epoch 15/30 Iteration: 19600 Avg. Training loss: 4.0743 0.0536 sec/batch
# Epoch 15/30 Iteration: 19700 Avg. Training loss: 4.0124 0.0537 sec/batch
# Epoch 15/30 Iteration: 19800 Avg. Training loss: 3.8093 0.0534 sec/batch
# Epoch 15/30 Iteration: 19900 Avg. Training loss: 3.9206 0.0531 sec/batch
# Epoch 15/30 Iteration: 20000 Avg. Training loss: 4.0529 0.0536 sec/batch
# Nearest to like: useful, fill, swayed, widows, principality, rigid, whither, hop'd,
# Nearest to she: herself, retraced, kirílovich, ornament, madam, thunder, hinders, meges,
# Nearest to i: perceive, believe, pasha, scheria, dead, knew'st, “really, providence,
# Nearest to when: superstition, bombs, weather, storm, lambton, cape, wheeled, artilleryman,
# Nearest to has: enticed, offers, covers, boylan, soothsayer, enables, jove's, byzantium,
# Nearest to any: eunuchs, companions, _have_, kurágin’s, enjoin, demanded, muddled, calmly,
# Nearest to could: capture, “more, trend, panthéon, delaford, being, hastily, relieve,
# Nearest to other: ‘there’s, bull’s, unemployed, cease, trellis, corioli, invisible, idolatry,
# Nearest to box: hoarded, peeps, quoted, pallor, antipodes, sweetness, tunic, harshness,
# Nearest to darkness: banking, strung, souvenirs, diffusion, await, pollution, linked, murdering,
# Nearest to hearing: attempting, schooles, repnín, prodigy, packet, visages, twitch, nuptial,
# Nearest to meeting: moth, behaving, week’s, whim, attention, scrutinizing, ceremony, disengage,
# Nearest to 3: 501, taunts, 1/2, quotes, higgins, squeak, £, inquisitively,
# Nearest to christ: technique, origin, perspiring, understanding, crushed, offerings, julie, emphasize,
# Nearest to pride: renaissance, affrights, dishonor, bred, and, mischievous, grosser, kingdom's,
# Nearest to brave: corrupt, valiant, glaring, quickly, respected, tremendously, disengaging, wart,
# Epoch 15/30 Iteration: 20100 Avg. Training loss: 3.8533 0.0538 sec/batch
# Epoch 15/30 Iteration: 20200 Avg. Training loss: 3.6706 0.0537 sec/batch
# Epoch 16/30 Iteration: 20300 Avg. Training loss: 4.0221 0.0027 sec/batch
# Epoch 16/30 Iteration: 20400 Avg. Training loss: 4.0884 0.0551 sec/batch
# Epoch 16/30 Iteration: 20500 Avg. Training loss: 3.8867 0.0543 sec/batch
# Epoch 16/30 Iteration: 20600 Avg. Training loss: 3.9455 0.0533 sec/batch
# Epoch 16/30 Iteration: 20700 Avg. Training loss: 3.9355 0.0534 sec/batch
# Epoch 16/30 Iteration: 20800 Avg. Training loss: 4.0547 0.0534 sec/batch
# Epoch 16/30 Iteration: 20900 Avg. Training loss: 4.0610 0.0542 sec/batch
# Epoch 16/30 Iteration: 21000 Avg. Training loss: 4.0667 0.0533 sec/batch
# Epoch 16/30 Iteration: 21100 Avg. Training loss: 3.8787 0.0536 sec/batch
# Epoch 16/30 Iteration: 21200 Avg. Training loss: 3.7992 0.0536 sec/batch
# Epoch 16/30 Iteration: 21300 Avg. Training loss: 4.0328 0.0534 sec/batch
# Epoch 16/30 Iteration: 21400 Avg. Training loss: 3.9955 0.0536 sec/batch
# Epoch 16/30 Iteration: 21500 Avg. Training loss: 3.7044 0.0531 sec/batch
# Epoch 16/30 Iteration: 21600 Avg. Training loss: 3.8142 0.0541 sec/batch
# Epoch 17/30 Iteration: 21700 Avg. Training loss: 4.0578 0.0283 sec/batch
# Epoch 17/30 Iteration: 21800 Avg. Training loss: 3.8982 0.0536 sec/batch
# Epoch 17/30 Iteration: 21900 Avg. Training loss: 3.8994 0.0532 sec/batch
# Epoch 17/30 Iteration: 22000 Avg. Training loss: 3.9623 0.0537 sec/batch
# Epoch 17/30 Iteration: 22100 Avg. Training loss: 3.9712 0.0546 sec/batch
# Epoch 17/30 Iteration: 22200 Avg. Training loss: 4.0356 0.0544 sec/batch
# Epoch 17/30 Iteration: 22300 Avg. Training loss: 4.0371 0.0544 sec/batch
# Epoch 17/30 Iteration: 22400 Avg. Training loss: 3.9838 0.0534 sec/batch
# Epoch 17/30 Iteration: 22500 Avg. Training loss: 3.7678 0.0534 sec/batch
# Epoch 17/30 Iteration: 22600 Avg. Training loss: 3.8523 0.0538 sec/batch
# Epoch 17/30 Iteration: 22700 Avg. Training loss: 4.0652 0.0537 sec/batch
# Epoch 17/30 Iteration: 22800 Avg. Training loss: 3.8556 0.0537 sec/batch
# Epoch 17/30 Iteration: 22900 Avg. Training loss: 3.6264 0.0541 sec/batch
# Epoch 17/30 Iteration: 23000 Avg. Training loss: 3.9729 0.0544 sec/batch
# Epoch 18/30 Iteration: 23100 Avg. Training loss: 4.0656 0.0539 sec/batch
# Epoch 18/30 Iteration: 23200 Avg. Training loss: 3.8453 0.0541 sec/batch
# Epoch 18/30 Iteration: 23300 Avg. Training loss: 3.9321 0.0542 sec/batch
# Epoch 18/30 Iteration: 23400 Avg. Training loss: 3.8927 0.0543 sec/batch
# Epoch 18/30 Iteration: 23500 Avg. Training loss: 4.0292 0.0539 sec/batch
# Epoch 18/30 Iteration: 23600 Avg. Training loss: 4.0345 0.0543 sec/batch
# Epoch 18/30 Iteration: 23700 Avg. Training loss: 4.0201 0.0544 sec/batch
# Epoch 18/30 Iteration: 23800 Avg. Training loss: 3.8667 0.0546 sec/batch
# Epoch 18/30 Iteration: 23900 Avg. Training loss: 3.7461 0.0542 sec/batch
# Epoch 18/30 Iteration: 24000 Avg. Training loss: 4.0111 0.0541 sec/batch
# Epoch 18/30 Iteration: 24100 Avg. Training loss: 3.9922 0.0547 sec/batch
# Epoch 18/30 Iteration: 24200 Avg. Training loss: 3.7182 0.0547 sec/batch
# Epoch 18/30 Iteration: 24300 Avg. Training loss: 3.7403 0.0542 sec/batch
# Epoch 19/30 Iteration: 24400 Avg. Training loss: 4.0018 0.0250 sec/batch
# Epoch 19/30 Iteration: 24500 Avg. Training loss: 3.9143 0.0539 sec/batch
# Epoch 19/30 Iteration: 24600 Avg. Training loss: 3.8471 0.0541 sec/batch
# Epoch 19/30 Iteration: 24700 Avg. Training loss: 3.9699 0.0540 sec/batch
# Epoch 19/30 Iteration: 24800 Avg. Training loss: 3.9441 0.0538 sec/batch
# Epoch 19/30 Iteration: 24900 Avg. Training loss: 4.0189 0.0541 sec/batch
# Epoch 19/30 Iteration: 25000 Avg. Training loss: 4.0596 0.0542 sec/batch
# Epoch 19/30 Iteration: 25100 Avg. Training loss: 3.9500 0.0538 sec/batch
# Epoch 19/30 Iteration: 25200 Avg. Training loss: 3.7574 0.0532 sec/batch
# Epoch 19/30 Iteration: 25300 Avg. Training loss: 3.7907 0.0537 sec/batch
# Epoch 19/30 Iteration: 25400 Avg. Training loss: 4.0417 0.0539 sec/batch
# Epoch 19/30 Iteration: 25500 Avg. Training loss: 3.8753 0.0552 sec/batch
# Epoch 19/30 Iteration: 25600 Avg. Training loss: 3.5513 0.0547 sec/batch
# Epoch 19/30 Iteration: 25700 Avg. Training loss: 3.9431 0.0541 sec/batch
# Epoch 20/30 Iteration: 25800 Avg. Training loss: 4.0658 0.0507 sec/batch
# Epoch 20/30 Iteration: 25900 Avg. Training loss: 3.8079 0.0539 sec/batch
# Epoch 20/30 Iteration: 26000 Avg. Training loss: 3.9382 0.0546 sec/batch
# Epoch 20/30 Iteration: 26100 Avg. Training loss: 3.8846 0.0547 sec/batch
# Epoch 20/30 Iteration: 26200 Avg. Training loss: 4.0258 0.0540 sec/batch
# Epoch 20/30 Iteration: 26300 Avg. Training loss: 4.0051 0.0560 sec/batch
# Epoch 20/30 Iteration: 26400 Avg. Training loss: 4.0050 0.0556 sec/batch
# Epoch 20/30 Iteration: 26500 Avg. Training loss: 3.8355 0.0552 sec/batch
# Epoch 20/30 Iteration: 26600 Avg. Training loss: 3.7481 0.0553 sec/batch
# Epoch 20/30 Iteration: 26700 Avg. Training loss: 3.9755 0.0541 sec/batch
# Epoch 20/30 Iteration: 26800 Avg. Training loss: 3.9349 0.0542 sec/batch
# Epoch 20/30 Iteration: 26900 Avg. Training loss: 3.6979 0.0545 sec/batch
# Epoch 20/30 Iteration: 27000 Avg. Training loss: 3.7196 0.0544 sec/batch
# Epoch 21/30 Iteration: 27100 Avg. Training loss: 4.0023 0.0216 sec/batch
# Epoch 21/30 Iteration: 27200 Avg. Training loss: 3.8797 0.0540 sec/batch
# Epoch 21/30 Iteration: 27300 Avg. Training loss: 3.8175 0.0539 sec/batch
# Epoch 21/30 Iteration: 27400 Avg. Training loss: 3.9543 0.0542 sec/batch
# Epoch 21/30 Iteration: 27500 Avg. Training loss: 3.9251 0.0540 sec/batch
# Epoch 21/30 Iteration: 27600 Avg. Training loss: 3.9914 0.0542 sec/batch
# Epoch 21/30 Iteration: 27700 Avg. Training loss: 3.9807 0.0543 sec/batch
# Epoch 21/30 Iteration: 27800 Avg. Training loss: 3.9628 0.0544 sec/batch
# Epoch 21/30 Iteration: 27900 Avg. Training loss: 3.7343 0.0540 sec/batch
# Epoch 21/30 Iteration: 28000 Avg. Training loss: 3.7942 0.0541 sec/batch
# Epoch 21/30 Iteration: 28100 Avg. Training loss: 3.9764 0.0536 sec/batch
# Epoch 21/30 Iteration: 28200 Avg. Training loss: 3.8640 0.0539 sec/batch
# Epoch 21/30 Iteration: 28300 Avg. Training loss: 3.5413 0.0543 sec/batch
# Epoch 21/30 Iteration: 28400 Avg. Training loss: 3.8993 0.0541 sec/batch
# Epoch 22/30 Iteration: 28500 Avg. Training loss: 4.0234 0.0476 sec/batch
# Epoch 22/30 Iteration: 28600 Avg. Training loss: 3.7947 0.0541 sec/batch
# Epoch 22/30 Iteration: 28700 Avg. Training loss: 3.8700 0.0546 sec/batch
# Epoch 22/30 Iteration: 28800 Avg. Training loss: 3.8619 0.0540 sec/batch
# Epoch 22/30 Iteration: 28900 Avg. Training loss: 3.9991 0.0537 sec/batch
# Epoch 22/30 Iteration: 29000 Avg. Training loss: 3.9914 0.0547 sec/batch
# Epoch 22/30 Iteration: 29100 Avg. Training loss: 4.0167 0.0546 sec/batch
# Epoch 22/30 Iteration: 29200 Avg. Training loss: 3.8260 0.0540 sec/batch
# Epoch 22/30 Iteration: 29300 Avg. Training loss: 3.6919 0.0540 sec/batch
# Epoch 22/30 Iteration: 29400 Avg. Training loss: 3.9354 0.0542 sec/batch
# Epoch 22/30 Iteration: 29500 Avg. Training loss: 3.9322 0.0537 sec/batch
# Epoch 22/30 Iteration: 29600 Avg. Training loss: 3.7098 0.0539 sec/batch
# Epoch 22/30 Iteration: 29700 Avg. Training loss: 3.6764 0.0543 sec/batch
# Epoch 23/30 Iteration: 29800 Avg. Training loss: 3.9792 0.0185 sec/batch
# Epoch 23/30 Iteration: 29900 Avg. Training loss: 3.8714 0.0540 sec/batch
# Epoch 23/30 Iteration: 30000 Avg. Training loss: 3.8247 0.0542 sec/batch
# Nearest to like: useful, inland, foliage, principality, naughty, fill, overcharged, hop'd,
# Nearest to she: herself, was, retraced, meges, professes, ornament, cleaving, addresses,
# Nearest to i: “really, myself, spunk, coroner, gratified, derived, think, blemishes,
# Nearest to when: superstition, bombs, winding, cape, sit, nothing, weather, curve,
# Nearest to has: enticed, boylan, covers, offers, you, friction, soothsayer, could,
# Nearest to any: eunuchs, companions, the, _have_, calmly, deletions, kurágin’s, triangle,
# Nearest to could: “more, capture, delaford, sympathetic, trend, “might, being, relieve,
# Nearest to other: bull’s, unemployed, jarring, unresisting, cease, corioli, ‘there’s, “andrew,
# Nearest to box: antipodes, hoarded, quoted, harden, discreetly, peeps, lid, tunic,
# Nearest to darkness: banking, den, souvenirs, await, scene, linked, strung, pollution,
# Nearest to hearing: visages, prodigy, packet, schooles, shepherds, mistakes, repnín, imply,
# Nearest to meeting: moth, week’s, whim, unlucky, attention, they’d, chunk, behaving,
# Nearest to 3: 501, 1/2, taunts, quotes, replacement, jourdain, pain, squeak,
# Nearest to christ: understanding, technique, preside, aegisthus, crucified, origin, perspiring, resurrection,
# Nearest to pride: _very_, and, affrights, covert, dishonor, kingdom's, stubbornness, adviser,
# Nearest to brave: corrupt, valiant, olive, pressed, disengaging, running, drench, outface,
# Epoch 23/30 Iteration: 30100 Avg. Training loss: 3.8970 0.0541 sec/batch
# Epoch 23/30 Iteration: 30200 Avg. Training loss: 3.9203 0.0539 sec/batch
# Epoch 23/30 Iteration: 30300 Avg. Training loss: 3.9799 0.0540 sec/batch
# Epoch 23/30 Iteration: 30400 Avg. Training loss: 3.9928 0.0545 sec/batch
# Epoch 23/30 Iteration: 30500 Avg. Training loss: 3.9412 0.0543 sec/batch
# Epoch 23/30 Iteration: 30600 Avg. Training loss: 3.7287 0.0532 sec/batch
# Epoch 23/30 Iteration: 30700 Avg. Training loss: 3.7404 0.0538 sec/batch
# Epoch 23/30 Iteration: 30800 Avg. Training loss: 3.9839 0.0539 sec/batch
# Epoch 23/30 Iteration: 30900 Avg. Training loss: 3.8935 0.0533 sec/batch
# Epoch 23/30 Iteration: 31000 Avg. Training loss: 3.5664 0.0541 sec/batch
# Epoch 23/30 Iteration: 31100 Avg. Training loss: 3.8683 0.0541 sec/batch
# Epoch 24/30 Iteration: 31200 Avg. Training loss: 4.0045 0.0439 sec/batch
# Epoch 24/30 Iteration: 31300 Avg. Training loss: 3.7747 0.0542 sec/batch
# Epoch 24/30 Iteration: 31400 Avg. Training loss: 3.8385 0.0540 sec/batch
# Epoch 24/30 Iteration: 31500 Avg. Training loss: 3.8450 0.0542 sec/batch
# Epoch 24/30 Iteration: 31600 Avg. Training loss: 3.9745 0.0539 sec/batch
# Epoch 24/30 Iteration: 31700 Avg. Training loss: 3.9860 0.0539 sec/batch
# Epoch 24/30 Iteration: 31800 Avg. Training loss: 4.0087 0.0539 sec/batch
# Epoch 24/30 Iteration: 31900 Avg. Training loss: 3.8102 0.0538 sec/batch
# Epoch 24/30 Iteration: 32000 Avg. Training loss: 3.6629 0.0539 sec/batch
# Epoch 24/30 Iteration: 32100 Avg. Training loss: 3.9033 0.0543 sec/batch
# Epoch 24/30 Iteration: 32200 Avg. Training loss: 3.9176 0.0540 sec/batch
# Epoch 24/30 Iteration: 32300 Avg. Training loss: 3.7267 0.0542 sec/batch
# Epoch 24/30 Iteration: 32400 Avg. Training loss: 3.6684 0.0542 sec/batch
# Epoch 25/30 Iteration: 32500 Avg. Training loss: 3.9328 0.0151 sec/batch
# Epoch 25/30 Iteration: 32600 Avg. Training loss: 3.9155 0.0537 sec/batch
# Epoch 25/30 Iteration: 32700 Avg. Training loss: 3.7831 0.0541 sec/batch
# Epoch 25/30 Iteration: 32800 Avg. Training loss: 3.8845 0.0539 sec/batch
# Epoch 25/30 Iteration: 32900 Avg. Training loss: 3.8726 0.0541 sec/batch
# Epoch 25/30 Iteration: 33000 Avg. Training loss: 3.9754 0.0537 sec/batch
# Epoch 25/30 Iteration: 33100 Avg. Training loss: 3.9663 0.0541 sec/batch
# Epoch 25/30 Iteration: 33200 Avg. Training loss: 3.9487 0.0542 sec/batch
# Epoch 25/30 Iteration: 33300 Avg. Training loss: 3.7309 0.0538 sec/batch
# Epoch 25/30 Iteration: 33400 Avg. Training loss: 3.6882 0.0540 sec/batch
# Epoch 25/30 Iteration: 33500 Avg. Training loss: 3.9955 0.0536 sec/batch
# Epoch 25/30 Iteration: 33600 Avg. Training loss: 3.8986 0.0540 sec/batch
# Epoch 25/30 Iteration: 33700 Avg. Training loss: 3.5503 0.0540 sec/batch
# Epoch 25/30 Iteration: 33800 Avg. Training loss: 3.8333 0.0541 sec/batch
# Epoch 26/30 Iteration: 33900 Avg. Training loss: 4.0268 0.0406 sec/batch
# Epoch 26/30 Iteration: 34000 Avg. Training loss: 3.7386 0.0539 sec/batch
# Epoch 26/30 Iteration: 34100 Avg. Training loss: 3.8207 0.0540 sec/batch
# Epoch 26/30 Iteration: 34200 Avg. Training loss: 3.8181 0.0539 sec/batch
# Epoch 26/30 Iteration: 34300 Avg. Training loss: 3.9326 0.0539 sec/batch
# Epoch 26/30 Iteration: 34400 Avg. Training loss: 4.0010 0.0537 sec/batch
# Epoch 26/30 Iteration: 34500 Avg. Training loss: 3.9701 0.0539 sec/batch
# Epoch 26/30 Iteration: 34600 Avg. Training loss: 3.8207 0.0535 sec/batch
# Epoch 26/30 Iteration: 34700 Avg. Training loss: 3.6654 0.0549 sec/batch
# Epoch 26/30 Iteration: 34800 Avg. Training loss: 3.8429 0.0539 sec/batch
# Epoch 26/30 Iteration: 34900 Avg. Training loss: 3.9518 0.0540 sec/batch
# Epoch 26/30 Iteration: 35000 Avg. Training loss: 3.6846 0.0541 sec/batch
# Epoch 26/30 Iteration: 35100 Avg. Training loss: 3.6146 0.0542 sec/batch
# Epoch 27/30 Iteration: 35200 Avg. Training loss: 3.9398 0.0118 sec/batch
# Epoch 27/30 Iteration: 35300 Avg. Training loss: 3.9040 0.0543 sec/batch
# Epoch 27/30 Iteration: 35400 Avg. Training loss: 3.7459 0.0539 sec/batch
# Epoch 27/30 Iteration: 35500 Avg. Training loss: 3.8791 0.0545 sec/batch
# Epoch 27/30 Iteration: 35600 Avg. Training loss: 3.8483 0.0544 sec/batch
# Epoch 27/30 Iteration: 35700 Avg. Training loss: 3.9683 0.0538 sec/batch
# Epoch 27/30 Iteration: 35800 Avg. Training loss: 3.9340 0.0543 sec/batch
# Epoch 27/30 Iteration: 35900 Avg. Training loss: 3.9272 0.0540 sec/batch
# Epoch 27/30 Iteration: 36000 Avg. Training loss: 3.7268 0.0537 sec/batch
# Epoch 27/30 Iteration: 36100 Avg. Training loss: 3.6706 0.0540 sec/batch
# Epoch 27/30 Iteration: 36200 Avg. Training loss: 3.9776 0.0541 sec/batch
# Epoch 27/30 Iteration: 36300 Avg. Training loss: 3.8890 0.0541 sec/batch
# Epoch 27/30 Iteration: 36400 Avg. Training loss: 3.5386 0.0541 sec/batch
# Epoch 27/30 Iteration: 36500 Avg. Training loss: 3.8150 0.0542 sec/batch
# Epoch 28/30 Iteration: 36600 Avg. Training loss: 3.9895 0.0374 sec/batch
# Epoch 28/30 Iteration: 36700 Avg. Training loss: 3.7132 0.0540 sec/batch
# Epoch 28/30 Iteration: 36800 Avg. Training loss: 3.8165 0.0539 sec/batch
# Epoch 28/30 Iteration: 36900 Avg. Training loss: 3.8118 0.0541 sec/batch
# Epoch 28/30 Iteration: 37000 Avg. Training loss: 3.9085 0.0538 sec/batch
# Epoch 28/30 Iteration: 37100 Avg. Training loss: 3.9696 0.0540 sec/batch
# Epoch 28/30 Iteration: 37200 Avg. Training loss: 3.9403 0.0550 sec/batch
# Epoch 28/30 Iteration: 37300 Avg. Training loss: 3.8259 0.0547 sec/batch
# Epoch 28/30 Iteration: 37400 Avg. Training loss: 3.6511 0.0535 sec/batch
# Epoch 28/30 Iteration: 37500 Avg. Training loss: 3.8211 0.0544 sec/batch
# Epoch 28/30 Iteration: 37600 Avg. Training loss: 3.9375 0.0552 sec/batch
# Epoch 28/30 Iteration: 37700 Avg. Training loss: 3.6564 0.0541 sec/batch
# Epoch 28/30 Iteration: 37800 Avg. Training loss: 3.6208 0.0544 sec/batch
# Epoch 29/30 Iteration: 37900 Avg. Training loss: 3.9175 0.0086 sec/batch
# Epoch 29/30 Iteration: 38000 Avg. Training loss: 3.9082 0.0544 sec/batch
# Epoch 29/30 Iteration: 38100 Avg. Training loss: 3.7429 0.0541 sec/batch
# Epoch 29/30 Iteration: 38200 Avg. Training loss: 3.8432 0.0543 sec/batch
# Epoch 29/30 Iteration: 38300 Avg. Training loss: 3.8363 0.0541 sec/batch
# Epoch 29/30 Iteration: 38400 Avg. Training loss: 3.9729 0.0541 sec/batch
# Epoch 29/30 Iteration: 38500 Avg. Training loss: 3.9100 0.0542 sec/batch
# Epoch 29/30 Iteration: 38600 Avg. Training loss: 3.9531 0.0538 sec/batch
# Epoch 29/30 Iteration: 38700 Avg. Training loss: 3.7389 0.0549 sec/batch
# Epoch 29/30 Iteration: 38800 Avg. Training loss: 3.6051 0.0541 sec/batch
# Epoch 29/30 Iteration: 38900 Avg. Training loss: 3.9774 0.0546 sec/batch
# Epoch 29/30 Iteration: 39000 Avg. Training loss: 3.8870 0.0540 sec/batch
# Epoch 29/30 Iteration: 39100 Avg. Training loss: 3.5570 0.0537 sec/batch
# Epoch 29/30 Iteration: 39200 Avg. Training loss: 3.7387 0.0537 sec/batch
# Epoch 30/30 Iteration: 39300 Avg. Training loss: 3.9559 0.0338 sec/batch
# Epoch 30/30 Iteration: 39400 Avg. Training loss: 3.7106 0.0536 sec/batch
# Epoch 30/30 Iteration: 39500 Avg. Training loss: 3.8132 0.0540 sec/batch
# Epoch 30/30 Iteration: 39600 Avg. Training loss: 3.8260 0.0538 sec/batch
# Epoch 30/30 Iteration: 39700 Avg. Training loss: 3.9094 0.0535 sec/batch
# Epoch 30/30 Iteration: 39800 Avg. Training loss: 3.9251 0.0538 sec/batch
# Epoch 30/30 Iteration: 39900 Avg. Training loss: 3.9485 0.0536 sec/batch
# Epoch 30/30 Iteration: 40000 Avg. Training loss: 3.8013 0.0536 sec/batch
# Nearest to like: hop'd, <PERIOD>, curse, malice, useful, principality, inland, precipice,
# Nearest to she: herself, was, opened, retraced, meges, sensations, grumbled, faut,
# Nearest to i: my, myself, am, <QUESTION_MARK>, me, owe, <PERIOD>, <COMMA>,
# Nearest to when: superstition, master, carry, now, cape, sit, weather, beast,
# Nearest to has: enticed, boylan, friction, offers, nos, covers, know, bail,
# Nearest to any: eunuchs, companions, nominal, or, triangle, demanded, _have_, prominently,
# Nearest to could: tried, trend, panthéon, delaford, intermittent, “more, frame, sensuality,
# Nearest to other: bull’s, thunderbolts, unemployed, unresisting, verily, fairer, jarring, lovers,
# Nearest to box: antipodes, quoted, patterns, opera, harden, hoarded, side, discreetly,
# Nearest to darkness: den, linked, souvenirs, shadow, pollution, await, banking, pursuits,
# Nearest to hearing: visages, imply, precipitation, briony, shepherds, mistakes, levin, commander,
# Nearest to meeting: unlucky, moth, blazing, whim, attention, week’s, behaving, army's,
# Nearest to 3: 501, 1/2, squeak, balance, replacement, £, pain, jourdain,
# Nearest to christ: understanding, aimed, puny, wooer, bigoted, preside, kingdomes, thereunto,
# Nearest to pride: _very_, stubbornness, covert, affrights, robert, adviser, kingdom's, ill,
# Nearest to brave: running, valiant, olive, pressed, estate, entry, testy, corrupt,
# Epoch 30/30 Iteration: 40100 Avg. Training loss: 3.6293 0.0537 sec/batch
# Epoch 30/30 Iteration: 40200 Avg. Training loss: 3.7764 0.0538 sec/batch
# Epoch 30/30 Iteration: 40300 Avg. Training loss: 3.9330 0.0537 sec/batch
# Epoch 30/30 Iteration: 40400 Avg. Training loss: 3.7086 0.0536 sec/batch
# Epoch 30/30 Iteration: 40500 Avg. Training loss: 3.5424 0.0537 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints_large'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
