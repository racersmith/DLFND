# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:45, 693KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter

word_counts = Counter(int_words)
word_counts[vocab_to_int['the']]
# Out:
# 1061396

# %%
train_words = []
from random import random
import numpy as np

def discard_prob(word_count, total_count, threshold):
    return 1 - np.sqrt(threshold/(word_count/total_count))

threshold = 1e-5

# Calculate the discard prob and store
total_words = len(int_words)
p_drop = {word: discard_prob(count, total_words, threshold) for word, count in word_counts.items()}

train_words = [word for word in int_words if p_drop[word] < random()]

print(train_words[:10])
# Out:
# [5236, 3081, 3133, 741, 476, 10611, 133, 27630, 15194, 61265]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
from random import randint

def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    
    sub_window = randint(1, window_size)
    
    targets = [words[idx - i - 1] for i in range(sub_window) if idx-i-1 >= 0]
    targets += [words[idx + i + 1] for i in range(sub_window) if idx+i+1 < len(words)]
#     targets = list(set(targets))
    targets = set(targets)
    return list(targets)

# %%
get_target(int_words, 5, window_size=2)
# Out:
# [194, 3133]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None], name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1), name='embedding')
    
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    # create softmax weight matrix here
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], mean=0, stddev=0.1))
    
    # create softmax biases here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, 
                                      biases=softmax_b, 
                                      labels=labels, 
                                      inputs=embed, 
                                      num_sampled=n_sampled, 
                                      num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6328 0.0672 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5989 0.0624 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5276 0.0637 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5965 0.0626 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4721 0.0635 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5345 0.0629 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5770 0.0630 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5750 0.0652 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4836 0.0647 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4081 0.0652 sec/batch
# Nearest to may: betrayal, astronaut, deposition, wig, quirks, jodie, sgh, els,
# Nearest to use: thw, pussycats, vab, nanosystems, affaires, apostrophe, exacting, theosis,
# Nearest to they: zephaniah, lonely, ralston, gaussian, couper, backup, cigarette, totem,
# Nearest to would: antiarrhythmic, fergus, convinced, credentials, oiler, schemas, hailstone, equivalent,
# Nearest to that: benzoic, chromatography, specialization, speculatively, have, bayliss, eastman, filling,
# Nearest to more: voicing, nsh, ephemera, hala, skyteam, himself, chipmunks, expressways,
# Nearest to known: jfduke, helped, copycat, federated, vig, msa, bureaucrats, alluded,
# Nearest to by: eked, waves, geiger, okedo, angra, finalized, infiniband, nas,
# Nearest to governor: espoused, foley, bacher, meditation, raining, abstained, albania, perrault,
# Nearest to derived: kapoor, salvadoran, empanadas, macha, frisian, milosevic, ribeira, inlays,
# Nearest to bill: salo, kyanite, shiki, colli, anshan, endangering, martinson, karsh,
# Nearest to square: philandering, tendencies, gulliver, falling, rodolfo, brutal, hierarchies, xerxes,
# Nearest to account: locke, dactylic, varieties, bretagne, atomists, darshan, indigo, weizenbaum,
# Nearest to accepted: moabites, upsurge, gutman, arsenals, khtml, stevenson, derek, insidious,
# Nearest to existence: biography, sketches, demilitarisation, ducts, disclaimer, mat, socratic, baka,
# Nearest to defense: argentines, violation, according, admixtures, catwalk, garnered, iis, koresh,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4665 0.0655 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3335 0.0650 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3292 0.0640 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2688 0.0643 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1782 0.0645 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1544 0.0646 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0798 0.0647 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0531 0.0640 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0176 0.0642 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9657 0.0646 sec/batch
# Nearest to may: betrayal, deposition, astronaut, utility, choose, progress, electric, fame,
# Nearest to use: how, thw, canadian, ucd, core, vab, relatively, theosis,
# Nearest to they: lonely, backup, lair, cigarette, points, orleans, adequate, gaussian,
# Nearest to would: convinced, equivalent, antiarrhythmic, schemas, tiger, irrigation, term, apartment,
# Nearest to that: society, finite, specialization, have, within, written, eastern, benzoic,
# Nearest to more: himself, voicing, nsh, weeks, wide, course, unix, expressways,
# Nearest to known: helped, jfduke, vig, past, federated, structuralism, physicians, senators,
# Nearest to by: waves, geiger, eked, syria, pressure, indies, finalized, references,
# Nearest to governor: espoused, foley, meditation, perrault, legalizing, hard, bacher, infringing,
# Nearest to derived: salvadoran, kapoor, empanadas, games, forest, macha, frisian, create,
# Nearest to bill: salo, kyanite, colli, endangering, anshan, protestants, shiki, household,
# Nearest to square: philandering, brutal, tendencies, falling, hierarchies, eat, regulation, ller,
# Nearest to account: varieties, locke, gross, sheer, dactylic, smaller, atomists, futility,
# Nearest to accepted: neil, conformity, stevenson, technology, cent, gutman, when, prestigious,
# Nearest to existence: biography, sent, mat, sensors, rome, sketches, encyclopaedia, timely,
# Nearest to defense: according, violation, argentines, garnered, divided, catwalk, admixtures, glyph,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9366 0.0653 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9024 0.0643 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8656 0.0644 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8873 0.0648 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8106 0.0644 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8178 0.0652 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8001 0.0645 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7913 0.0642 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7887 0.0646 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7858 0.0651 sec/batch
# Nearest to may: deposition, astronaut, betrayal, wig, quirks, boards, choose, electric,
# Nearest to use: thw, how, vab, affaires, exposing, core, theosis, ucd,
# Nearest to they: lonely, cigarette, backup, correspondents, adequate, zephaniah, cape, couper,
# Nearest to would: convinced, antiarrhythmic, equivalent, persia, schemas, oiler, credentials, box,
# Nearest to that: finite, specialization, society, have, written, renaming, occurrences, silicon,
# Nearest to more: himself, nsh, voicing, rally, skyteam, expressways, dv, weeks,
# Nearest to known: helped, jfduke, senators, physicians, federated, structuralism, copycat, bureaucrats,
# Nearest to by: syria, finalized, conform, retains, daddy, geiger, pressure, suppression,
# Nearest to governor: espoused, infringing, impeachment, legalizing, foley, perrault, meditation, richest,
# Nearest to derived: salvadoran, empanadas, kapoor, frisian, create, macha, games, graphical,
# Nearest to bill: salo, kyanite, endangering, colli, anshan, protestants, why, shiki,
# Nearest to square: brutal, philandering, tendencies, falling, regulation, eat, hierarchies, ller,
# Nearest to account: locke, dactylic, varieties, gross, indigo, atomists, futility, sheer,
# Nearest to accepted: stevenson, gutman, conformity, neil, upsurge, derek, prestigious, infallible,
# Nearest to existence: biography, sensors, sketches, ducts, socratic, timely, mat, sent,
# Nearest to defense: according, violation, argentines, divided, garnered, negotiate, catwalk, conservative,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7752 0.0662 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7540 0.0652 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7142 0.0633 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7295 0.0627 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7338 0.0630 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6983 0.0644 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7146 0.0636 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7145 0.0633 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7104 0.0632 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6656 0.0624 sec/batch
# Nearest to may: wig, deposition, quirks, astronaut, boards, betrayal, guessing, folding,
# Nearest to use: vab, thw, how, theosis, affaires, exacting, heliport, exposing,
# Nearest to they: lonely, cigarette, backup, correspondents, zephaniah, adequate, totem, ralston,
# Nearest to would: antiarrhythmic, convinced, persia, equivalent, schemas, credentials, antagonism, fergus,
# Nearest to that: specialization, finite, society, renaming, have, occurrences, written, dembski,
# Nearest to more: nsh, himself, voicing, skyteam, dv, hala, medium, chaos,
# Nearest to known: helped, jfduke, physicians, senators, copycat, bureaucrats, integrals, structuralism,
# Nearest to by: syria, finalized, suppression, accurately, eked, retains, geiger, conform,
# Nearest to governor: espoused, perrault, impeachment, legalizing, albania, infringing, elected, foley,
# Nearest to derived: salvadoran, empanadas, kapoor, macha, frisian, gameboy, create, lesbianism,
# Nearest to bill: salo, endangering, kyanite, protestants, anshan, colli, shiki, why,
# Nearest to square: philandering, brutal, tendencies, rodolfo, falling, gulliver, regulation, antiope,
# Nearest to account: dactylic, locke, gross, indigo, futility, unwritten, atomists, weizenbaum,
# Nearest to accepted: upsurge, gutman, conformity, semiotics, stevenson, arsenals, moabites, epileptic,
# Nearest to existence: sensors, socratic, ducts, invariance, disclaimer, mat, biography, sketches,
# Nearest to defense: according, violation, argentines, glyph, garnered, divided, admixtures, catwalk,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6598 0.0630 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6596 0.0653 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6229 0.0636 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6458 0.0628 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6310 0.0624 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6135 0.0628 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5837 0.0448 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5415 0.0624 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4993 0.0621 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5061 0.0649 sec/batch
# Nearest to may: wig, deposition, quirks, boards, cartridge, bertram, astronaut, countered,
# Nearest to use: vab, users, theosis, how, thw, affaires, heliport, retrograde,
# Nearest to they: lonely, backup, cigarette, correspondents, zephaniah, occupants, ralston, points,
# Nearest to would: antiarrhythmic, convinced, persia, equivalent, credentials, fergus, schemas, antagonism,
# Nearest to that: finite, specialization, society, have, renaming, occurrences, physiological, written,
# Nearest to more: nsh, skyteam, himself, voicing, dv, hala, medium, lackey,
# Nearest to known: jfduke, helped, copycat, physicians, senators, structuralism, integrals, sarcastic,
# Nearest to by: syria, eked, finalized, deterioration, geiger, weavers, suppression, mediators,
# Nearest to governor: elected, impeachment, espoused, perrault, aemilius, legalizing, states, chairman,
# Nearest to derived: salvadoran, empanadas, macha, create, kapoor, lesbianism, gameboy, bitwise,
# Nearest to bill: salo, endangering, kyanite, karsh, shiki, cleanse, protestants, colli,
# Nearest to square: brutal, philandering, xerxes, rodolfo, falling, gulliver, tajik, tendencies,
# Nearest to account: locke, dactylic, indigo, unwritten, gross, weizenbaum, factoring, fishman,
# Nearest to accepted: moabites, upsurge, gutman, platonism, semiotics, stevenson, arsenals, conformity,
# Nearest to existence: sensors, invariance, socratic, ducts, disclaimer, sketches, pistons, demilitarisation,
# Nearest to defense: violation, according, argentines, glyph, divided, garnered, koresh, admixtures,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4957 0.0633 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5076 0.0628 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4422 0.0629 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5220 0.0622 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4959 0.0625 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4687 0.0631 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4643 0.0625 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4146 0.0628 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4107 0.0637 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4018 0.0627 sec/batch
# Nearest to may: wig, deposition, quirks, boards, folding, guessing, choose, bertram,
# Nearest to use: users, vab, thw, theosis, how, ability, retrograde, heliport,
# Nearest to they: zephaniah, cigarette, lonely, backup, correspondents, leaved, adequate, occupants,
# Nearest to would: antiarrhythmic, convinced, equivalent, antagonism, persia, oiler, droplets, schemas,
# Nearest to that: finite, society, chromatography, specialization, have, within, written, gallows,
# Nearest to more: nsh, skyteam, himself, voicing, advantage, initial, lackey, medium,
# Nearest to known: jfduke, copycat, helped, physicians, structuralism, alluded, integrals, msa,
# Nearest to by: eked, finalized, syria, retains, daddy, philosophies, bromberg, deterioration,
# Nearest to governor: elected, impeachment, chairman, aemilius, espoused, perrault, rias, states,
# Nearest to derived: empanadas, salvadoran, lesbianism, create, gameboy, macha, identically, bitwise,
# Nearest to bill: salo, endangering, cleanse, karsh, kyanite, sven, maureen, bono,
# Nearest to square: brutal, xerxes, philandering, rodolfo, gulliver, falling, regulation, reservoir,
# Nearest to account: dactylic, locke, unwritten, indigo, gross, outsourcing, futility, weizenbaum,
# Nearest to accepted: moabites, upsurge, conformity, platonism, gutman, when, semiotics, real,
# Nearest to existence: socratic, invariance, ducts, sensors, disclaimer, doesn, observe, pistons,
# Nearest to defense: violation, according, argentines, koresh, glyph, garnered, divided, admixtures,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4518 0.0626 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4269 0.0622 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4370 0.0623 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3975 0.0625 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4222 0.0619 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4535 0.0622 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3886 0.0626 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3943 0.0627 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4108 0.0628 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3785 0.0627 sec/batch
# Nearest to may: deposition, wig, folding, guessing, choose, quirks, bertram, illness,
# Nearest to use: users, thw, vab, retrograde, affaires, heliport, core, disks,
# Nearest to they: zephaniah, caste, lonely, cigarette, leaved, backup, fooled, adequate,
# Nearest to would: antiarrhythmic, convinced, antagonism, droplets, persia, credentials, redskins, put,
# Nearest to that: finite, society, have, physiological, chromatography, selflessness, within, specialization,
# Nearest to more: nsh, skyteam, advantage, voicing, lackey, himself, rationality, dv,
# Nearest to known: jfduke, copycat, homographs, structuralism, integrals, helped, physicians, warden,
# Nearest to by: eked, bromberg, infiniband, finalized, weavers, accurately, retains, deterioration,
# Nearest to governor: elected, impeachment, chairman, aemilius, espoused, perrault, rias, commonwealth,
# Nearest to derived: empanadas, lesbianism, gameboy, identically, bitwise, salvadoran, create, frisian,
# Nearest to bill: salo, endangering, karsh, cleanse, kyanite, sven, hyde, quarterbacks,
# Nearest to square: brutal, xerxes, rodolfo, philandering, falling, tajik, antiope, reservoir,
# Nearest to account: dactylic, tangent, unwritten, locke, factoring, indigo, fishman, gross,
# Nearest to accepted: moabites, upsurge, conformity, platonism, gutman, when, mellor, without,
# Nearest to existence: invariance, socratic, ducts, disclaimer, gradient, observe, sensors, timely,
# Nearest to defense: violation, argentines, according, glyph, koresh, astrometrics, divided, admixtures,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3695 0.0629 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4180 0.0614 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3667 0.0620 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3876 0.0615 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4100 0.0624 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3855 0.0634 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4180 0.0628 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3858 0.0630 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3440 0.0630 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3156 0.0629 sec/batch
# Nearest to may: wig, deposition, folding, bertram, illness, choose, guessing, boards,
# Nearest to use: users, vab, retrograde, thw, disks, core, affaires, inordinate,
# Nearest to they: zephaniah, leaved, caste, fooled, lonely, occupants, backup, rationality,
# Nearest to would: antiarrhythmic, convinced, antagonism, droplets, credentials, equivalent, dua, put,
# Nearest to that: finite, have, gallows, society, specialization, within, resistors, dismantlement,
# Nearest to more: nsh, skyteam, advantage, voicing, lackey, uniformed, rationality, auger,
# Nearest to known: jfduke, copycat, homographs, spoilers, msa, structuralism, helped, warden,
# Nearest to by: finalized, eked, syria, weavers, daddy, sovereign, suppression, philosophies,
# Nearest to governor: elected, impeachment, chairman, espoused, aemilius, senators, gosford, legalizing,
# Nearest to derived: gameboy, empanadas, identically, frisian, salvadoran, lesbianism, bitwise, harmony,
# Nearest to bill: salo, kyanite, endangering, cleanse, matth, karsh, shiki, beacons,
# Nearest to square: brutal, xerxes, rodolfo, falling, antiope, tajik, bottlers, colloquially,
# Nearest to account: unwritten, dactylic, locke, tangent, indigo, factoring, gross, fishman,
# Nearest to accepted: moabites, conformity, upsurge, gutman, platonism, infallible, when, kbos,
# Nearest to existence: socratic, invariance, disclaimer, ducts, observe, gradient, beings, demilitarisation,
# Nearest to defense: violation, argentines, koresh, according, glyph, astrometrics, immediate, military,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3442 0.0640 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2983 0.0635 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3561 0.0630 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3887 0.0636 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3826 0.0633 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2809 0.0639 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3029 0.0633 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3304 0.0631 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2174 0.0634 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2845 0.0626 sec/batch
# Nearest to may: wig, deposition, folding, quirks, bertram, guessing, presence, leverage,
# Nearest to use: users, retrograde, vab, thw, barque, deprecate, disks, nanosystems,
# Nearest to they: fooled, zephaniah, leaved, interpretative, caste, backup, occupants, cigarette,
# Nearest to would: antiarrhythmic, convinced, droplets, equivalent, antagonism, dua, credentials, put,
# Nearest to that: finite, have, resistors, gallows, litigation, obvious, physiological, hostility,
# Nearest to more: nsh, skyteam, advantage, voicing, uniformed, himself, hala, lackey,
# Nearest to known: jfduke, copycat, spoilers, msa, homographs, pterosaurs, structuralism, sarcastic,
# Nearest to by: eked, weavers, suppression, finalized, bromberg, nations, sovereign, philosophies,
# Nearest to governor: elected, impeachment, chairman, aemilius, espoused, appoints, senators, gosford,
# Nearest to derived: lesbianism, salvadoran, gameboy, frisian, empanadas, bitwise, inscriptions, harmony,
# Nearest to bill: salo, karsh, kyanite, quarterbacks, maureen, shiki, cleanse, matth,
# Nearest to square: xerxes, brutal, rodolfo, tajik, eta, antiope, falling, bottlers,
# Nearest to account: dactylic, unwritten, tangent, gross, indigo, locke, weizenbaum, kops,
# Nearest to accepted: moabites, upsurge, platonism, conformity, gutman, cumann, mellor, kbos,
# Nearest to existence: socratic, disclaimer, invariance, ducts, observe, demilitarisation, immortality, beings,
# Nearest to defense: violation, argentines, koresh, astrometrics, glyph, immediate, according, military,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2884 0.0637 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2684 0.0629 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3265 0.0282 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2448 0.0637 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2089 0.0634 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2074 0.0639 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1987 0.0630 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2344 0.0638 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2048 0.0631 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1798 0.0632 sec/batch
# Nearest to may: wig, deposition, aino, haart, bertram, folding, quirks, biopolymers,
# Nearest to use: thw, retrograde, users, affaires, deprecate, apostrophe, nanosystems, barque,
# Nearest to they: fooled, zephaniah, leaved, adequate, interpretative, caste, cigarette, points,
# Nearest to would: convinced, antiarrhythmic, unattractive, credentials, antagonism, put, dua, equivalent,
# Nearest to that: resistors, finite, gallows, litigation, have, hostility, reals, samplers,
# Nearest to more: nsh, uniformed, skyteam, voicing, advantage, lackey, claws, everyone,
# Nearest to known: copycat, jfduke, homographs, pterosaurs, spoilers, msa, sarcastic, brito,
# Nearest to by: eked, weavers, bromberg, finalized, prefectural, pressure, indies, syria,
# Nearest to governor: elected, impeachment, senators, appoints, espoused, chairman, gosford, legislature,
# Nearest to derived: identically, empanadas, lesbianism, gameboy, bitwise, inscriptions, salvadoran, frisian,
# Nearest to bill: salo, quarterbacks, maureen, kyanite, karsh, bono, cleanse, mprp,
# Nearest to square: xerxes, tajik, eta, rodolfo, brutal, bottlers, traverses, colloquially,
# Nearest to account: dactylic, unwritten, locke, tangent, gross, darshan, indigo, kops,
# Nearest to accepted: moabites, platonism, conformity, infallible, upsurge, kbos, mellor, cumann,
# Nearest to existence: socratic, invariance, disclaimer, ducts, immortality, observe, demilitarisation, mat,
# Nearest to defense: violation, astrometrics, glyph, argentines, immediate, koresh, anti, military,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2595 0.0642 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2055 0.0632 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2255 0.0639 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1492 0.0637 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1775 0.0645 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1581 0.0639 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1717 0.0636 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1691 0.0637 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1841 0.0640 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1764 0.0636 sec/batch
# Nearest to may: wig, deposition, presence, guessing, biopolymers, folding, leverage, xe,
# Nearest to use: thw, affaires, users, deprecate, nanosystems, vab, retrograde, altogether,
# Nearest to they: fooled, backup, zephaniah, interpretative, leaved, adequate, points, cigarette,
# Nearest to would: convinced, antiarrhythmic, unattractive, antagonism, put, dua, droplets, equivalent,
# Nearest to that: resistors, finite, have, within, reals, gallows, chromatography, samplers,
# Nearest to more: nsh, uniformed, voicing, advantage, skyteam, himself, claws, everyone,
# Nearest to known: copycat, pterosaurs, jfduke, homographs, msa, brito, spoilers, spherical,
# Nearest to by: eked, finalized, bromberg, weavers, rhombic, philosophies, infiniband, nations,
# Nearest to governor: elected, impeachment, appoints, senators, espoused, chairman, legislature, aemilius,
# Nearest to derived: inscriptions, lesbianism, bitwise, identically, empanadas, gameboy, frisian, shrubs,
# Nearest to bill: salo, quarterbacks, kyanite, maureen, karsh, bono, shiki, mprp,
# Nearest to square: tajik, eta, brutal, xerxes, notated, bottlers, rodolfo, grid,
# Nearest to account: unwritten, dactylic, locke, tangent, gross, darshan, indigo, kops,
# Nearest to accepted: moabites, platonism, conformity, mellor, upsurge, infallible, kbos, misrepresenting,
# Nearest to existence: invariance, socratic, disclaimer, immortality, ducts, observe, demilitarisation, forensic,
# Nearest to defense: violation, astrometrics, immediate, koresh, argentines, glyph, military, according,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1699 0.0647 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2138 0.0648 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1668 0.0643 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1364 0.0643 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1705 0.0643 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1729 0.0634 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1910 0.0628 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1770 0.0630 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1486 0.0631 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1703 0.0628 sec/batch
# Nearest to may: wig, haart, aino, presence, xe, quirks, folding, biopolymers,
# Nearest to use: thw, deprecate, affaires, altogether, vab, users, nanosystems, retrograde,
# Nearest to they: fooled, interpretative, zephaniah, caste, adequate, leaved, backup, xenophobia,
# Nearest to would: convinced, antiarrhythmic, unattractive, antagonism, equivalent, put, duryodhana, dua,
# Nearest to that: resistors, finite, have, litigation, it, reals, chromatography, gallows,
# Nearest to more: nsh, advantage, uniformed, himself, skyteam, voicing, flaw, course,
# Nearest to known: copycat, jfduke, pterosaurs, brito, homographs, msa, spoilers, structuralism,
# Nearest to by: philosophies, eked, bromberg, amenable, weavers, pressure, references, accurately,
# Nearest to governor: elected, impeachment, appoints, legislature, senators, espoused, chairman, gosford,
# Nearest to derived: frisian, lesbianism, identically, inscriptions, bitwise, gameboy, empanadas, shrubs,
# Nearest to bill: salo, quarterbacks, kyanite, maureen, karsh, shiki, endangering, chronometer,
# Nearest to square: tajik, notated, eta, xerxes, traverses, brutal, bottlers, rodolfo,
# Nearest to account: unwritten, tangent, dactylic, gross, locke, indigo, darshan, kops,
# Nearest to accepted: platonism, moabites, upsurge, infallible, cumann, conformity, mellor, elazar,
# Nearest to existence: invariance, socratic, disclaimer, observe, immortality, ducts, demilitarisation, forensic,
# Nearest to defense: violation, military, immediate, koresh, astrometrics, argentines, glyph, according,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2049 0.0634 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1617 0.0634 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.2007 0.0632 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1903 0.0635 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1585 0.0637 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1350 0.0629 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1580 0.0638 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1288 0.0647 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1811 0.0640 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2069 0.0638 sec/batch
# Nearest to may: wig, haart, marvelman, aino, leverage, guessing, bertram, presence,
# Nearest to use: thw, deprecate, affaires, nanosystems, apostrophe, inordinate, retrograde, vab,
# Nearest to they: leaved, interpretative, zephaniah, childless, adequate, fooled, caste, lynching,
# Nearest to would: convinced, antagonism, unattractive, antiarrhythmic, put, duryodhana, equivalent, someday,
# Nearest to that: refuses, gallows, litigation, have, it, resistors, denouncing, the,
# Nearest to more: nsh, uniformed, himself, advantage, skyteam, voicing, hala, everyone,
# Nearest to known: jfduke, copycat, pterosaurs, spoilers, connaught, helped, homographs, brito,
# Nearest to by: finalized, deprive, eked, constituci, weavers, prefectural, indies, barents,
# Nearest to governor: elected, impeachment, appoints, senators, legislature, gosford, espoused, pierce,
# Nearest to derived: lesbianism, frisian, inscriptions, identically, gameboy, bitwise, empanadas, harmony,
# Nearest to bill: salo, maureen, quarterbacks, kyanite, prosecution, mprp, bono, shiki,
# Nearest to square: tajik, notated, eta, brutal, traverses, xerxes, rodolfo, bottlers,
# Nearest to account: dactylic, locke, unwritten, tangent, gross, indigo, darshan, vers,
# Nearest to accepted: platonism, moabites, conformity, mellor, cumann, infallible, upsurge, gutman,
# Nearest to existence: invariance, socratic, disclaimer, immortality, observe, balochis, demilitarisation, forensic,
# Nearest to defense: violation, military, immediate, astrometrics, koresh, according, argentines, memorandum,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2472 0.0645 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1501 0.0639 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1197 0.0641 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1484 0.0634 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0485 0.0640 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1466 0.0643 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1412 0.0638 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1448 0.0646 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1510 0.0104 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1338 0.0634 sec/batch
# Nearest to may: aino, haart, marvelman, wig, biopolymers, quirks, guessing, antidepressant,
# Nearest to use: thw, affaires, deprecate, altogether, retrograde, apostrophe, inordinate, nanosystems,
# Nearest to they: leaved, fooled, zephaniah, adequate, interpretative, childless, backup, lonely,
# Nearest to would: convinced, antiarrhythmic, unattractive, equivalent, antagonism, droplets, duryodhana, this,
# Nearest to that: resistors, have, it, within, gallows, overturned, finite, refuses,
# Nearest to more: nsh, uniformed, advantage, himself, everyone, skyteam, voicing, claws,
# Nearest to known: pterosaurs, copycat, jfduke, homographs, brito, photography, spoilers, msa,
# Nearest to by: weavers, driven, pressure, eked, accurately, constituci, mediators, eastwards,
# Nearest to governor: elected, impeachment, senators, appoints, legislature, espoused, gosford, pierce,
# Nearest to derived: inscriptions, lesbianism, frisian, gameboy, bitwise, empanadas, identically, salvadoran,
# Nearest to bill: kyanite, salo, quarterbacks, shiki, maureen, bono, prosecution, endangering,
# Nearest to square: tajik, traverses, eta, notated, cdots, xerxes, brutal, bottlers,
# Nearest to account: dactylic, tangent, gross, darshan, locke, unwritten, indigo, kops,
# Nearest to accepted: platonism, moabites, mellor, cumann, infallible, conformity, upsurge, should,
# Nearest to existence: invariance, socratic, disclaimer, balochis, demilitarisation, immortality, forensic, observe,
# Nearest to defense: violation, military, astrometrics, immediate, koresh, argentines, donelson, commandant,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0703 0.0642 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0502 0.0632 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0734 0.0641 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0345 0.0641 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0764 0.0630 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0360 0.0629 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0837 0.0626 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0571 0.0628 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1356 0.0623 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0265 0.0628 sec/batch
# Nearest to may: haart, biopolymers, aino, antidepressant, guessing, marvelman, quirks, xe,
# Nearest to use: thw, affaires, deprecate, altogether, nanosystems, mothersbaugh, apostrophe, users,
# Nearest to they: fooled, leaved, childless, zephaniah, adequate, lynching, interpretative, backup,
# Nearest to would: convinced, antiarrhythmic, unattractive, antagonism, this, equivalent, put, duryodhana,
# Nearest to that: resistors, have, it, within, the, finite, them, chromatography,
# Nearest to more: nsh, uniformed, advantage, claws, himself, tropics, gravitated, colder,
# Nearest to known: pterosaurs, copycat, homographs, jfduke, archeological, brito, spoilers, connaught,
# Nearest to by: driven, pressure, accurately, of, weavers, sovereign, manorialism, bromberg,
# Nearest to governor: impeachment, elected, legislature, senators, appoints, espoused, pierce, gosford,
# Nearest to derived: inscriptions, identically, lesbianism, bitwise, empanadas, gameboy, frisian, salvadoran,
# Nearest to bill: quarterbacks, salo, kyanite, shiki, maureen, bono, karsh, martinson,
# Nearest to square: eta, tajik, traverses, cdots, brutal, bottlers, notated, circle,
# Nearest to account: dactylic, gross, locke, tangent, unwritten, darshan, kops, vers,
# Nearest to accepted: platonism, infallible, mellor, moabites, cumann, conformity, yah, upsurge,
# Nearest to existence: balochis, socratic, invariance, disclaimer, immortality, demilitarisation, observe, arthropod,
# Nearest to defense: violation, military, immediate, astrometrics, according, koresh, obstacles, argentines,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0222 0.0634 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0441 0.0631 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0096 0.0629 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0629 0.0629 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0594 0.0631 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0579 0.0630 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0555 0.0628 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1109 0.0631 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0664 0.0626 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0279 0.0630 sec/batch
# Nearest to may: guessing, haart, biopolymers, marvelman, aino, antidepressant, presence, leverage,
# Nearest to use: thw, affaires, deprecate, altogether, relatively, apostrophe, retrograde, adopters,
# Nearest to they: fooled, zephaniah, childless, backup, interpretative, leaved, adequate, lynching,
# Nearest to would: convinced, unattractive, antagonism, this, equivalent, put, antiarrhythmic, persisting,
# Nearest to that: resistors, the, have, it, this, chromatography, within, finite,
# Nearest to more: nsh, advantage, uniformed, himself, everyone, ther, voicing, tropics,
# Nearest to known: pterosaurs, copycat, photography, jfduke, brito, fountain, adventurous, archeological,
# Nearest to by: accurately, of, pressure, rhombic, driven, extensional, mediators, sovereign,
# Nearest to governor: impeachment, elected, senators, legislature, appoints, pierce, espoused, gosford,
# Nearest to derived: inscriptions, lesbianism, identically, empanadas, bitwise, frisian, gameboy, wumpus,
# Nearest to bill: quarterbacks, kyanite, salo, maureen, shiki, karsh, bono, martinson,
# Nearest to square: eta, cdots, traverses, circle, notated, tajik, grid, brutal,
# Nearest to account: gross, tangent, underemployment, darshan, dactylic, locke, kops, factoring,
# Nearest to accepted: platonism, mellor, infallible, upsurge, cumann, misrepresenting, moabites, conformity,
# Nearest to existence: socratic, invariance, disclaimer, immortality, balochis, observe, wields, beings,
# Nearest to defense: violation, military, astrometrics, immediate, commandant, memorandum, koresh, equalization,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0387 0.0639 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0845 0.0630 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0648 0.0629 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0596 0.0635 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0648 0.0630 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0388 0.0639 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0901 0.0631 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0556 0.0643 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0917 0.0646 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0742 0.0640 sec/batch
# Nearest to may: haart, marvelman, guessing, aino, biopolymers, bertram, omission, leverage,
# Nearest to use: thw, deprecate, affaires, altogether, xerox, mutombo, feminine, relatively,
# Nearest to they: zephaniah, childless, leaved, backup, fooled, cedars, caste, adequate,
# Nearest to would: convinced, unattractive, antagonism, antiarrhythmic, equivalent, duryodhana, put, this,
# Nearest to that: resistors, it, have, the, this, within, finite, man,
# Nearest to more: advantage, nsh, uniformed, himself, ther, voicing, everyone, tropics,
# Nearest to known: pterosaurs, archeological, jfduke, copycat, homographs, fountain, brito, photography,
# Nearest to by: of, driven, the, sovereign, constituci, eastwards, weavers, which,
# Nearest to governor: elected, impeachment, legislature, appoints, senators, espoused, pierce, gosford,
# Nearest to derived: identically, inscriptions, lesbianism, empanadas, bitwise, gameboy, frisian, wumpus,
# Nearest to bill: kyanite, salo, quarterbacks, endangering, bono, maureen, prosecution, beacons,
# Nearest to square: eta, notated, cdots, traverses, tajik, circle, brutal, multiplications,
# Nearest to account: gross, tangent, dactylic, kops, darshan, indigo, locke, underemployment,
# Nearest to accepted: infallible, platonism, moabites, upsurge, misrepresenting, elazar, cumann, yah,
# Nearest to existence: socratic, balochis, disclaimer, immortality, invariance, observe, wields, demilitarisation,
# Nearest to defense: violation, military, astrometrics, commandant, donelson, immediate, memorandum, koresh,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0198 0.0638 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0314 0.0631 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0553 0.0629 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0579 0.0638 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0795 0.0651 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1362 0.0647 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1466 0.0639 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0264 0.0641 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0366 0.0641 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0516 0.0633 sec/batch
# Nearest to may: haart, aino, leverage, marvelman, biopolymers, guessing, keyword, omission,
# Nearest to use: deprecate, thw, affaires, adopters, apostrophe, mutombo, etymologically, altogether,
# Nearest to they: fooled, zephaniah, interpretative, cedars, childless, adequate, leaved, caste,
# Nearest to would: convinced, unattractive, equivalent, this, antagonism, duryodhana, antiarrhythmic, moose,
# Nearest to that: resistors, it, have, the, this, refuses, within, posthuman,
# Nearest to more: advantage, nsh, uniformed, ther, himself, tropics, voicing, claws,
# Nearest to known: pterosaurs, brito, jfduke, archeological, connaught, copycat, fountain, photography,
# Nearest to by: driven, constituci, of, accurately, weavers, pressure, deprive, extensional,
# Nearest to governor: elected, impeachment, legislature, senators, appoints, espoused, pierce, gosford,
# Nearest to derived: empanadas, lesbianism, identically, gameboy, inscriptions, bitwise, lebanon, frisian,
# Nearest to bill: kyanite, quarterbacks, maureen, salo, shiki, bono, prosecution, beacons,
# Nearest to square: traverses, notated, eta, cdots, circle, tajik, brutal, overbending,
# Nearest to account: gross, tangent, dactylic, kops, underemployment, locke, unwritten, darshan,
# Nearest to accepted: platonism, infallible, upsurge, cumann, mellor, misrepresenting, chamorros, casimir,
# Nearest to existence: socratic, balochis, disclaimer, invariance, observe, immortality, wields, demilitarisation,
# Nearest to defense: violation, military, astrometrics, commandant, koresh, anti, nuclear, according,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9890 0.0642 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0400 0.0643 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0417 0.0647 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0309 0.0641 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0699 0.0637 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0484 0.0573 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0019 0.0637 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9885 0.0641 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0116 0.0641 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9832 0.0646 sec/batch
# Nearest to may: aino, haart, marvelman, biopolymers, omission, guessing, presence, bertram,
# Nearest to use: deprecate, thw, affaires, etymologically, semipalatinsk, altogether, mutombo, methodologies,
# Nearest to they: cedars, fooled, childless, zephaniah, adequate, interpretative, caste, judaeo,
# Nearest to would: convinced, unattractive, this, did, equivalent, maximilian, antagonism, antiarrhythmic,
# Nearest to that: it, resistors, have, this, the, within, felt, mates,
# Nearest to more: nsh, advantage, uniformed, ther, tropics, everyone, claws, himself,
# Nearest to known: pterosaurs, archeological, homographs, photography, copycat, fountain, jfduke, brito,
# Nearest to by: driven, extensional, of, weavers, accurately, constituci, eastwards, pressure,
# Nearest to governor: impeachment, legislature, elected, senators, appoints, espoused, pierce, gosford,
# Nearest to derived: inscriptions, empanadas, gameboy, identically, lesbianism, tur, lebanon, bitwise,
# Nearest to bill: kyanite, maureen, quarterbacks, shiki, salo, bono, karsh, hyde,
# Nearest to square: traverses, cdots, circle, eta, notated, overbending, tajik, brutal,
# Nearest to account: dactylic, tangent, gross, kops, demons, darshan, locke, alchemy,
# Nearest to accepted: platonism, infallible, moabites, misrepresenting, cumann, upsurge, kbos, chamorros,
# Nearest to existence: socratic, balochis, disclaimer, immortality, invariance, wields, arthropod, essaioi,
# Nearest to defense: violation, military, astrometrics, commandant, mandate, argentines, nuclear, koresh,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9933 0.0642 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9581 0.0642 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0382 0.0637 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0413 0.0635 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9966 0.0630 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0124 0.0640 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9186 0.0632 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9451 0.0631 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9552 0.0634 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9831 0.0633 sec/batch
# Nearest to may: biopolymers, aino, leverage, haart, guessing, antidepressant, keyword, marvelman,
# Nearest to use: deprecate, affaires, thw, altogether, semipalatinsk, mutombo, etymologically, photorealistic,
# Nearest to they: cedars, childless, adequate, fooled, backup, zephaniah, xenophobia, judaeo,
# Nearest to would: convinced, this, unattractive, equivalent, did, antiarrhythmic, very, launched,
# Nearest to that: it, this, resistors, have, the, finite, within, chromatography,
# Nearest to more: advantage, nsh, uniformed, ther, considered, squeezes, tropics, estimated,
# Nearest to known: pterosaurs, archeological, fountain, photography, copycat, jfduke, msa, adventurous,
# Nearest to by: driven, extensional, of, pressure, mediators, which, rhombic, references,
# Nearest to governor: impeachment, legislature, elected, senators, appoints, espoused, gosford, administer,
# Nearest to derived: empanadas, identically, lesbianism, inscriptions, lebanon, bitwise, tur, gameboy,
# Nearest to bill: kyanite, maureen, quarterbacks, salo, shiki, karsh, hyde, bono,
# Nearest to square: traverses, circle, cdots, tajik, eta, brutal, notated, overbending,
# Nearest to account: gross, kops, underemployment, tangent, dactylic, locke, accounted, sheer,
# Nearest to accepted: platonism, infallible, cumann, misrepresenting, moabites, upsurge, kbos, chamorros,
# Nearest to existence: socratic, balochis, disclaimer, invariance, wields, immortality, essaioi, forensic,
# Nearest to defense: violation, military, astrometrics, argentines, mandate, commandant, robins, immediate,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9934 0.0641 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0020 0.0630 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9525 0.0632 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0141 0.0633 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0256 0.0634 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9491 0.0631 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0051 0.0634 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0048 0.0630 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9757 0.0635 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9927 0.0630 sec/batch
# Nearest to may: aino, haart, leverage, marvelman, guessing, omission, biopolymers, antidepressant,
# Nearest to use: deprecate, affaires, thw, altogether, mothersbaugh, doe, etymologically, mutombo,
# Nearest to they: cedars, interpretative, fooled, adequate, childless, xenophobia, backup, zephaniah,
# Nearest to would: convinced, unattractive, this, did, equivalent, very, antagonism, antiarrhythmic,
# Nearest to that: it, the, this, have, resistors, and, than, felt,
# Nearest to more: advantage, nsh, uniformed, considered, individuals, himself, everyone, ther,
# Nearest to known: pterosaurs, archeological, adventurous, photography, copycat, brito, fountain, erhard,
# Nearest to by: of, driven, the, extensional, in, which, a, references,
# Nearest to governor: impeachment, elected, legislature, senators, appoints, pierce, espoused, gosford,
# Nearest to derived: lesbianism, inscriptions, identically, empanadas, lebanon, frisian, tur, wumpus,
# Nearest to bill: kyanite, maureen, shiki, quarterbacks, salo, hyde, endangering, martinson,
# Nearest to square: circle, brutal, cdots, traverses, eta, notated, overbending, tajik,
# Nearest to account: gross, underemployment, kops, tangent, accounted, beets, sheer, spending,
# Nearest to accepted: platonism, misrepresenting, cumann, infallible, mellor, chamorros, upsurge, kbos,
# Nearest to existence: socratic, balochis, disclaimer, wields, invariance, essaioi, immortality, encyclopaedia,
# Nearest to defense: violation, military, astrometrics, mandate, immediate, argentines, equalization, sufficiency,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0063 0.0644 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9981 0.0630 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9628 0.0636 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0078 0.0638 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9943 0.0632 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9850 0.0634 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9804 0.0636 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9362 0.0636 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9627 0.0631 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0354 0.0640 sec/batch
# Nearest to may: aino, guessing, haart, leverage, biopolymers, omission, marvelman, jurisdictions,
# ...
# Nearest to would: to, did, this, convinced, very, but, so, unattractive,
# Nearest to that: it, the, this, is, and, have, to, a,
# Nearest to more: advantage, considered, are, nsh, have, estimated, bushes, individuals,
# Nearest to known: in, pterosaurs, widely, birthstone, as, some, collegium, erhard,
# Nearest to by: the, a, of, in, and, which, from, to,
# Nearest to governor: legislature, appoints, espoused, impeachment, falsifying, departments, administer, cabinet,
# Nearest to derived: inscriptions, tur, derives, struts, wumpus, name, meaning, nihilo,
# Nearest to bill: moor, kyanite, hyde, stan, salo, clef, endangering, chronometer,
# Nearest to square: overbending, brutal, lutes, cdots, notated, accuser, residential, traverses,
# Nearest to account: gross, underemployment, beets, sheer, ephesians, measurements, tangent, vitellius,
# Nearest to accepted: kbos, bosniaks, judaean, platonism, headstrong, kantor, chamorros, activate,
# Nearest to existence: balochis, encyclopaedia, wields, essaioi, absorbs, astrophysicists, socratic, serber,
# Nearest to defense: robins, sufficiency, mandate, interception, military, knudsen, heisman, violation,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8297 0.0670 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8707 0.0667 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8596 0.0657 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8839 0.0659 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8612 0.0665 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8779 0.0661 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8728 0.0668 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8473 0.0641 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8912 0.0658 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8495 0.0666 sec/batch
# Nearest to may: begins, all, biopolymers, sessile, pastorius, a, gregorian, leverage,
# Nearest to use: some, other, etymologically, for, commonly, micheal, using, deprecate,
# Nearest to they: their, to, have, are, other, together, were, cedars,
# Nearest to would: did, convinced, to, very, not, unattractive, this, but,
# Nearest to that: it, the, this, to, a, is, not, but,
# Nearest to more: advantage, considered, are, nsh, have, tend, has, than,
# Nearest to known: in, pterosaurs, widely, some, collegium, as, birthstone, erhard,
# Nearest to by: the, a, of, in, and, which, from, to,
# Nearest to governor: legislature, appoints, espoused, impeachment, departments, falsifying, cabinet, administer,
# Nearest to derived: inscriptions, derives, name, tur, meaning, wumpus, nihilo, struts,
# Nearest to bill: kyanite, moor, endangering, salo, chronometer, hyde, krieger, stan,
# Nearest to square: overbending, accuser, notated, cdots, brutal, lutes, traverses, eta,
# Nearest to account: gross, underemployment, ephesians, measurements, tangent, beets, vitellius, correct,
# Nearest to accepted: kbos, platonism, bosniaks, indefensible, infallible, coexistence, judaean, chamorros,
# Nearest to existence: balochis, encyclopaedia, absorbs, wields, essaioi, astrophysicists, socratic, serber,
# Nearest to defense: military, sufficiency, mandate, robins, interception, knudsen, heisman, immediate,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8636 0.0672 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8538 0.0668 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8096 0.0667 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8307 0.0668 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8741 0.0669 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8254 0.0669 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9374 0.0680 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9265 0.0669 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9437 0.0665 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8409 0.0676 sec/batch
# Nearest to may: begins, all, sessile, degrees, biopolymers, uncommonly, evangelist, pastorius,
# Nearest to use: some, for, have, commonly, using, etymologically, other, micheal,
# Nearest to they: their, to, have, other, were, are, cedars, together,
# Nearest to would: did, to, convinced, but, this, unattractive, very, that,
# Nearest to that: it, the, this, not, is, to, but, have,
# Nearest to more: are, advantage, considered, nsh, tah, has, have, bushes,
# Nearest to known: in, widely, erhard, some, radiocommunication, pterosaurs, as, birthstone,
# Nearest to by: the, a, of, in, and, which, from, one,
# Nearest to governor: legislature, espoused, appoints, impeachment, falsifying, departments, administer, cabinet,
# Nearest to derived: inscriptions, tur, derives, wumpus, name, meaning, nihilo, dan,
# Nearest to bill: kyanite, moor, endangering, hyde, salo, chronometer, stan, chambers,
# Nearest to square: accuser, overbending, brutal, notated, cdots, lutes, residential, traverses,
# Nearest to account: gross, underemployment, ephesians, vitellius, beets, tangent, measurements, thebes,
# Nearest to accepted: kbos, bosniaks, chamorros, platonism, reform, indefensible, judaean, coexistence,
# Nearest to existence: balochis, encyclopaedia, wields, essaioi, absorbs, astrophysicists, socratic, serber,
# Nearest to defense: military, mandate, sufficiency, knudsen, interception, robins, heisman, immediate,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7900 0.0682 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8838 0.0686 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8050 0.0676 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8733 0.0667 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8732 0.0657 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8102 0.0638 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9122 0.0307 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8395 0.0641 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8287 0.0641 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8453 0.0634 sec/batch
# Nearest to may: biopolymers, sessile, gregorian, begins, all, degrees, pastorius, dakini,
# Nearest to use: some, have, for, other, micheal, etymologically, developed, affaires,
# Nearest to they: their, to, have, were, other, together, would, and,
# Nearest to would: did, to, convinced, this, unattractive, but, they, hypothetical,
# Nearest to that: it, the, to, is, a, have, there, this,
# Nearest to more: advantage, considered, estimated, nsh, are, bushes, than, have,
# Nearest to known: in, widely, erhard, as, pterosaurs, some, birthstone, collegium,
# Nearest to by: the, a, of, in, and, from, which, to,
# Nearest to governor: legislature, appoints, espoused, impeachment, cabinet, falsifying, administer, departments,
# Nearest to derived: name, derives, tur, inscriptions, meaning, wumpus, struts, isaac,
# Nearest to bill: kyanite, hyde, moor, stan, salo, endangering, krieger, chronometer,
# Nearest to square: overbending, accuser, cdots, malls, lutes, brutal, residential, notated,
# Nearest to account: gross, underemployment, ephesians, vitellius, thebes, tangent, dactylic, measurements,
# Nearest to accepted: kbos, platonism, bosniaks, chamorros, headstrong, infallible, judaean, indefensible,
# Nearest to existence: balochis, wields, encyclopaedia, astrophysicists, essaioi, socratic, sponsors, absorbs,
# Nearest to defense: military, mandate, sufficiency, interception, knudsen, robins, heisman, astrometrics,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7996 0.0651 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8193 0.0645 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8346 0.0636 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7939 0.0639 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8654 0.0632 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8563 0.0637 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8714 0.0637 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7648 0.0634 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8004 0.0634 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7898 0.0652 sec/batch
# Nearest to may: biopolymers, all, is, begins, to, not, degrees, a,
# Nearest to use: some, commonly, other, for, have, developed, using, etymologically,
# Nearest to they: to, their, other, are, and, have, together, were,
# Nearest to would: did, convinced, to, so, but, unattractive, this, they,
# Nearest to that: it, the, this, a, to, is, not, have,
# Nearest to more: advantage, considered, are, than, nsh, estimated, have, has,
# Nearest to known: in, widely, as, some, other, pterosaurs, collegium, birthstone,
# Nearest to by: the, a, in, of, which, and, to, from,
# Nearest to governor: legislature, appoints, impeachment, espoused, administer, falsifying, cabinet, departments,
# Nearest to derived: name, derives, inscriptions, tur, struts, meaning, wumpus, nihilo,
# Nearest to bill: kyanite, moor, salo, endangering, clef, stan, hyde, chronometer,
# Nearest to square: overbending, accuser, brutal, cdots, lutes, malls, traverses, notated,
# Nearest to account: gross, underemployment, ephesians, measurements, vitellius, accounted, thebes, tangent,
# Nearest to accepted: kbos, platonism, bosniaks, chamorros, headstrong, indefensible, universally, judaean,
# Nearest to existence: balochis, wields, encyclopaedia, astrophysicists, essaioi, absorbs, socratic, arthropod,
# Nearest to defense: military, interception, mandate, sufficiency, knudsen, robins, heisman, according,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7781 0.0649 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8118 0.0646 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8710 0.0648 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8190 0.0651 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8045 0.0656 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9025 0.0634 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8385 0.0640 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8402 0.0650 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8272 0.0634 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8391 0.0635 sec/batch
# Nearest to may: all, begins, not, biopolymers, a, on, is, sessile,
# Nearest to use: other, some, have, and, a, commonly, for, developed,
# Nearest to they: their, to, other, are, have, and, were, some,
# Nearest to would: did, convinced, to, unattractive, but, so, very, not,
# Nearest to that: the, it, is, to, this, a, not, have,
# Nearest to more: advantage, considered, are, have, than, estimated, has, somewhat,
# Nearest to known: in, widely, some, as, erhard, generally, pterosaurs, radiocommunication,
# Nearest to by: the, a, in, of, and, which, to, from,
# Nearest to governor: legislature, appoints, impeachment, espoused, departments, administer, cabinet, falsifying,
# Nearest to derived: derives, name, tur, inscriptions, meaning, popular, etymology, wumpus,
# Nearest to bill: kyanite, moor, hyde, endangering, stan, salo, chronometer, krieger,
# Nearest to square: overbending, brutal, accuser, cdots, lutes, notated, malls, eta,
# Nearest to account: gross, underemployment, ephesians, measurements, vitellius, tangent, correct, factoring,
# Nearest to accepted: kbos, fewer, chamorros, platonism, universally, bosniaks, annalen, kantor,
# Nearest to existence: astrophysicists, encyclopaedia, absorbs, essaioi, arthropod, balochis, wields, dynasty,
# Nearest to defense: knudsen, military, interception, sufficiency, mandate, robins, heisman, astrometrics,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8992 0.0647 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8056 0.0641 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8309 0.0650 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8499 0.0641 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8782 0.0641 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8421 0.0633 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8232 0.0637 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8510 0.0637 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8332 0.0640 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8107 0.0630 sec/batch
# Nearest to may: in, a, all, not, begins, biopolymers, is, on,
# Nearest to use: some, other, for, have, and, a, developed, commonly,
# Nearest to they: their, to, are, other, have, some, and, were,
# Nearest to would: did, to, convinced, this, unattractive, but, so, not,
# Nearest to that: it, the, this, is, not, a, to, have,
# Nearest to more: advantage, are, have, has, considered, for, estimated, up,
# Nearest to known: in, widely, some, as, pterosaurs, generally, erhard, birthstone,
# Nearest to by: the, a, of, in, and, which, from, to,
# Nearest to governor: legislature, appoints, espoused, impeachment, departments, administer, cabinet, override,
# Nearest to derived: derives, name, inscriptions, meaning, tur, popular, etymology, meanings,
# Nearest to bill: kyanite, endangering, moor, hyde, chronometer, clinton, salo, krieger,
# Nearest to square: accuser, overbending, cdots, brutal, lutes, sakaguchi, eta, notated,
# Nearest to account: gross, ephesians, underemployment, measurements, correct, vitellius, beets, relativistic,
# Nearest to accepted: fewer, bosniaks, universally, kbos, congregationalist, platonism, infallible, chamorros,
# Nearest to existence: astrophysicists, encyclopaedia, essaioi, absorbs, balochis, dynasty, arthropod, serber,
# Nearest to defense: military, mandate, sufficiency, knudsen, interception, heisman, robins, astrometrics,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8608 0.0639 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8272 0.0649 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9042 0.0642 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8861 0.0649 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8970 0.0638 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8381 0.0645 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7858 0.0633 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8225 0.0629 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7359 0.0652 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8784 0.0655 sec/batch
# Nearest to may: all, biopolymers, not, begins, haart, cardiology, sessile, are,
# Nearest to use: some, other, for, have, using, commonly, etymologically, a,
# Nearest to they: their, to, other, are, have, so, and, not,
# Nearest to would: did, convinced, to, so, but, unattractive, this, not,
# Nearest to that: it, is, the, to, not, a, this, there,
# Nearest to more: advantage, are, than, have, has, bushes, for, estimated,
# Nearest to known: in, some, widely, erhard, as, pterosaurs, generally, birthstone,
# Nearest to by: the, of, a, in, and, from, which, to,
# Nearest to governor: legislature, espoused, impeachment, appoints, departments, administer, cabinet, falsifying,
# Nearest to derived: derives, meaning, inscriptions, tur, name, popular, etymology, isaac,
# Nearest to bill: kyanite, moor, chronometer, hyde, endangering, salo, krieger, nikki,
# Nearest to square: accuser, overbending, cdots, vermont, traverses, lutes, sakaguchi, eta,
# Nearest to account: gross, underemployment, ephesians, correct, measurements, beets, relativistic, tangent,
# Nearest to accepted: kbos, bosniaks, universally, chamorros, coexistence, seasonally, infallible, disagreement,
# Nearest to existence: encyclopaedia, astrophysicists, essaioi, absorbs, balochis, serber, dynasty, arthropod,
# Nearest to defense: military, mandate, interception, sufficiency, knudsen, heisman, robins, immediate,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8508 0.0647 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8331 0.0634 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# Out:
# /home/josh/anaconda3/envs/dl/lib/python3.5/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
